# %%
import sys  
import os
import pandas as pd
import re

# %% [markdown]
# ## Helper Functions to Read Text File
#
# code from http://stackabuse.com/read-a-file-line-by-line-in-python/

# %%
def order_bag_of_words(bag_of_words, desc=False):  
   words = [(word, cnt) for word, cnt in bag_of_words.items()]
   return sorted(words, key=lambda x: x[1], reverse=desc)

# %%
def record_word_cnt(words, bag_of_words):  
   for word in words:
       if word != '':
           if word.lower() in bag_of_words:
               bag_of_words[word.lower()] += 1
           else:
               bag_of_words[word.lower()] = 0

# %%
# filepath = sys.argv[1]
def openfile(filepath):
    if not os.path.isfile(filepath):
       print("File path {} does not exist. Exiting...".format(filepath))
       sys.exit()

    return_array = []
        
    with open(filepath) as fp:
       for line in fp:
           return_array.append(line)
    
    return return_array

# %% [markdown]
# ## Read Text File

# %%
lines = openfile('1990-election-results-raw.txt')

# %% [markdown]
# First we take a look at the the names of constituencies

# %%
for (i,line) in enumerate(lines):
    lines[i] = lines[i].strip()

# %%
for (i,line) in enumerate(lines):
    if "cand." in line:
        print("\nline " + str(i-1) + ": " + lines[i-1] + '\n' + ' '.join('{}'.format(k) for k in line.split(";")))
# Out:
# line 0: Kayan-1 (Yangon)
# 41,226  33,996  31,328  4 cand.
#
# line 4: Kayan-2 (Yangon)
# 40,018  32,524  28,841  6 cand.
#
# line 8: Wakema-2 (Ayeyarwady)
# 72,831  49,584  41,528  4 cand.
#
# line 17: Mandalay North East-1 (Mandalay)
# 37,046  30,833  29,005  8 cand.
#
# line 21: Minbu-1 (Magway)
# 43,600  31,928  28,506  6 cand.
#
# line 25: Minbu-2 (Magway)
# 42,102  28,063  24,456  3 cand.
#
# line 30: Mandalay North West-2 (Mandalay)
# 50,451  38,0943  35,234  6 cand.
#
# line 34: Ngaphe (Magway)
# 21,337  17,077  15,107  3 cand.
#
# line 38: Mandalay North East-2 (Mandalay)
# 38,885  30,746  29,401  6 cand.
#
# line 42: Kunyangonn (Yangon)
# 56,590  47,680  42,287  6 cand.
#
# line 46: Patheingyi-1 (Mandalay)
# 36,244  27,769  24,662  6 cand.
#
# line 50: Patheingyi-2 (Mandalay)
# 34,087  27,070  24,014  7 cand.
#
# line 55: Kyaiklat-1 (Ayeyarwady)
# 45,458  35,056  30,873  4 cand.
#
# line 59: Kyaiklat-2 (Ayeyarwady)
# 46,027  33,590  29,710  4 cand.
#
# line 63: Pyapon-2 (Ayeyarwady)
# 52684  34,758  31,864  5 cand.
#
# line 67: Dedaye-2 (Ayeyarwady)
# 52,412  39,577  34,384  6 cand.
#
# line 71: Nattalin-1 (Bago)
# 47,418  38,764  33,017  4 cand.
#
# line 75: Nattalin-2 (Bago)
# 48,088  37,488  32,112  5 cand.
#
# line 79: Amarapura-1 (Mandalay)
# 42,741  34,831  31,829  6 cand.
#
# line 83: Amarapura-2 (Mandalay)
# 43,735  37,185  35,226  5 cand.
#
# line 88: Hlegu-1 (Yangon)
# 79,523  54,235  45,831  4 cand.
#
# line 92: Hlegu-2 (Yangon)
# 30,784  23,143  20,344  5 cand.
#
# line 96: Kyauktan-1 (Yangon)
# 37,399  31,668  26,200  4 cand.
#
# line 100: Kyauktan-2 (Yangon)
# 34,840  28,169  24,602  3 cand.
#
# line 104: Kyobingauk-1 (Bago)
# 35,256  25,007  21,079  5 cand.
#
# line 108: Okpo-1 (Bago)
# 34,368  23,523  19,700  6 cand.
#
# line 112: Okpo-2 (Bago)
# 39,086  26,435  22,873  7 cand.
#
# line 116: Zigon {Bago)
# 41,957  33,429  28,158  5 cand.
#
# line 120: Minhla-1 (Bago)
# 36,120  27,489  24,366  5 cand.
#
# line 125: 35,260; 23,568; [not given, but valid votes tallied equal votes
# cast]  5 cand.
#
# line 129: Bhamo (Kachin)
# 48,181  32,055  27,550  6 cand.
#
# line 133: Momauk (Kachin)
# 13,104  7,602  6,501  6 cand.
#
# line 141: 648 10%
# 77,887  62,961  57,674  7 cand.
#
# line 145: Myaung-2 (Sagaing)
# 33,485  26,741  24,205  5 cand.
#
# line 153: Myinmu-1 (Sagaing)
# 29,892  24,679  22,545  4 cand.
#
# line 157: Myinmu-2 (Sagaing)
# 30,935  24,653  22,398  3 cand.
#
# line 161: Myaung-1 (Sagaing)
# 33,415  26,885  24,747  5 cand.
#
# line 169: Ngazun-1 (Sagaing)
# 39,852  28,600  24,881  3 cand.
#
# line 173: Sagaing-1 (Sagaing)
# 71,844  58,103  52,772  8 cand.
#
# line 177: Ngazun-2 (Sagaing)
# 40,271  30,722  25,676  3 cand.
#
# line 182: Kyaukkyi (Bago)
# 43,167  23,512  20,343  3 cand.
#
# line 186: Taungoo-1 (Bago)
# 54,044  35,458  31,543  6 cand.
#
# line 190: Taungoo-2 (Bago)
# 55,749  36,178  30,405  5 cand.
#
# line 194: Pyay-1 [Prome] (Bago)
# 59,592  40,181  35,315  7 cand.
#
# line 199: Pyay-2 (Bago)
# 62,493  40,662  36768  6 cand.
#
# line 203: Paukkaung (Bago)
# 56,337  39,412  35,063  8 cand.
#
# line 208: Thayarwady-1 (Bago)
# 42,498  32,283  27,877  6 cand.
#
# line 212: Thayarwady-2 (Bago)
# 42,597  28,446  24,473  6 cand.
#
# line 216: Maubin-1 (Ayeyarwady)
# 78,823  57,426  49,787  6 cand.
#
# line 220: Maubin-2 (Ayeyarwady)
# 79,605  52,563  46,628  5 cand.
#
# line 224: Kalaw (Shan)
# 62,010  37,984  31,178  6 cand.
#
# line 232: Mansi (Kachin)
# 7,447  5,362  4,387  4 cand.
#
# line 240: Mandalay North West-1 (Mandalay)
# 46,015  38,138  36,630  6 cand.
#
# line 244: Mandalay South East-1 (Mandalay)
# 46,419  39,253  36,910  8 cand.
#
# line 248: Mandalay South East-2 (Mandalay)
# 58,988  46,326  43,002  6 cand.
#
# line 252: Thayetchaung (Tanintharyi)
# 33,182  21,697  17,038  4 cand.
#
# line 256: Launglon-1 (Tanintharyi)
# 37,442  25,133  19,614  3 cand.
#
# line 260: Launglon-2 (Tanintharyi)
# 33,723  22,759  18,015  3 cand.
#
# line 264: Dawei-1 [Tavoy] (Tanintharyi)
# 34,527  23,456  20,110  3 cand.
#
# line 268: Dawei-2 (Tanintharyi)
# 34,766  23,677  20,656  3 cand.
#
# line 273: Kyaikmaraw-1 (Mon)
# 39,948  24,640  19,968  5 cand.
#
# line 281: Kyaikmaraw-2 (Mon)
# 44,824  32,550  27,517  6 cand.
#
# line 289: Dedaye-1 (Ayeyarwady)
# 49076  35,788  30,884  3 cand.
#
# line 293: Yedashe-1 (Bago)
# 42,297  32,544  27,413  4 cand.
#
# line 297: Yedashe-2 (Bago)
# 43,647  32,784  29,014  3 cand.
#
# line 301: Pyu-1 (Bago)
# 47,205  31,432  27,392  4 cand.
#
# line 305: Pyu-2 (Bago)
# 65,024  41,432  36,948  5 cand.
#
# line 310: Htantabin (Bago)
# 50,435  36,471  30,089  4 cand.
#
# line 314: Oktwin-1 (Bago)
# 32,918  23,535  18,228  5 cand.
#
# line 318: Oktwin-2 (Bago)
# 31,257  22,696  19,561  4 cand.
#
# line 322: Myingyan-1 (Mandalay)
# 81,169  64,928  59,943  6 cand.
#
# line 326: Myingyan-2 (Mandalay)
# 80,385  62,136  57,415  4 cand.
#
# line 330: Pasawng (Kayah)
# 7,753  3,574  3,121  4 cand.
#
# line 334: Pruhso (Kayah)
# 9,237  3,330  2,739  4 cand.
#
# line 343: Dimawhso-1 (Kayah)
# 12,187  5,658  4,778  5 cand.
#
# line 351: Dimawhso-2 (Kayah)
# 12,209  8,535  7,044  3 cand.
#
# line 360: Loikaw-1 (Kayah)
# 19,854  12,659  11,647  4 cand.
#
# line 368: Loikaw-2 (Kayah)
# 21,536  12,272  10,688  6 cand.
#
# line 376: Bawlake (Kayah)
# 2,575  1,831  1,426  4 cand.
#
# line 387: Shataw (Kayah)
# 2,546  871  735  4 cand.
#
# line 395: Thanbyuzayat-1 (Mon)
# 37,004  27,185  24,156  5 cand.
#
# line 404: 3081 13%
# 42,114  28,353  24,086  4 cand.
#
# line 412: Thegon-2 (Bago)
# 40,248  28,050  24,925  4 cand.
#
# line 418: Shwedaung-1 (Bago)
# 40,926  30,797  27,709  7 cand.
#
# line 426: Shwedaung-2 (Bago)
# 40,989  27,001  23,976  6 cand.
#
# line 430: Paungde-1 (Bago)
# 40,222  29,939  24,329  4 cand.
#
# line 434: Paungde-2 (Bago)
# 39,381  29,545  23,846  4 cand.
#
# line 438: Padaung-1 (Bago)
# 42,763  26,532  23,077  5 cand.
#
# line 442: Padaung-2 (Bago)
# 44,615  31,106  27,023  5 cand.
#
# line 446: Monywa-1 (Sagaing)
# 82,559  65,476  61,225  5 cand.
#
# line 451: Monywa-2 (Sagaing)
# 81,434  64,205  60,695  7 cand.
#
# line 455: Salingyi-1 (Sagaing)
# 34,866  25,263  23,512  4 cand.
#
# line 459: Salingyi-2 (Sagaing)
# 32,356  24,513  21,421  3 cand.
#
# line 464: Pale-1 (Sagaing)
# 34,071  26,498  23,045  3 cand.
#
# line 468: Pale-2 (Sagaing)
# 33,195  24,264  20,759  4 cand.
#
# line 472: Kani-1 (Sagaing)
# 30,501  23,751  22,147  3 cand.
#
# line 476: Kani-2 (Sagaing)
# 31,839  24,972  22,755  3 cand.
#
# line 480: Chaung-U (Sagaing)
# 52,736  41,320  36,367  6 cand.
#
# line 484: Yinmabin-1 (Sagaing)
# 31,513  23,399  20,876  5 cand.
#
# line 489: Yinmabin-2 (Sagaing)
# 31,162  24,424  21,278  4 cand.
#
# line 494: Ywangan (Shan)
# 28,996  23,488  18,168  3 cand.
#
# line 503: Taungtha-1 (Mandalay)
# 62,509  47,853  44,393  4 cand.
#
# line 508: Taungtha-2 (Mandalay)
# 63,115  47,343  42,749  4 cand.
#
# line 512: Minbya-1 (Rakhine)
# 40,237  27,084  22,286  7 cand.
#
# line 521: Minbya-2 (Rakhine)
# 37,764  25,233  20,431  6 cand.
#
# line 530: Shwegu (Kachin)
# 26,266  17,790  15,483  4 cand.
#
# line 534: Natogyi-1 (Mandalay)
# 53,791  40,749  37,129  7 cand.
#
# line 539: Natogyi-2 (Mandalay)
# 53,780  38,887  35,723  7 cand.
#
# line 543: Nyaung-U-1 (Mandalay)
# 62,471  48,605  43,241  4 cand.
#
# line 547: Nyaung-U-2 (Mandalay)
# 62,910  45,294  40,648  3 cand.
#
# line 551: Kyaukpadaung-1 (Mandalay)
# 72,304  55,038  49,837  4 cand.
#
# line 556: Kyaukpadaung-2 (Mandalay)
# 72,245  58,629  52,215  4 cand.
#
# line 560: Tatkon-1 (Mandalay)
# 53,097  41,960  38,092  4 cand.
#
# line 564: Tatkon-2 (Mandalay)
# 53,515  41,886  36,312  4 cand.
#
# line 568: Pyawbwe-1 (Mandalay)
# 63,462  49,801  45,075  5 cand.
#
# line 572: Pyawbwe-2 (Mandalay)
# 61,031  43,280  36,739  4 cand.
#
# line 576: Yamethin-1 (Mandalay)
# 55,779  45,228  40,579  5 cand.
#
# line 584: Yamethin-2 (Mandalay)
# 54,319  41,270  36,575  5 cand.
#
# line 588: Sittwe-1 (Rakhine)
# 49,899  36,441  30,332  8 cand.
#
# line 601: 2547  8%
# 59,033  36,755  32,815  5 cand.
#
# line 605: Thaton-2 (Mon)
# 63,217  41,316  36,704  7 cand.
#
# line 609: Thandaung-1 (Kayin)
# 15,507  9736  8554  3 cand.
#
# line 615: Thandaung-2 (Kayin)
# 11,369  6,383  5,605  3 cand.
#
# line 619: Hlaingbwe-1 (Kayin)
# 28,735  12,901  10,190  4 cand.
#
# line 628: Hlaingbwe-2 (Kayin)
# 26,312  13,003  10,674  4 cand.
#
# line 632: Salin-1 (Magway)
# 62,001  44,769  40,054  4 cand.
#
# line 636: Salin-2 (Magway)
# 58,806  43,365  39,697  3 cand.
#
# line 640: Pwintbyu-1 (Magway)
# 39,767  30,471  26,645  5 cand.
#
# line 644: Pwintbyu-2 (Magway)
# 42,271  34,418  30,573  3 cand.
#
# line 648: Sedoktara (Magway)
# 22,537  18,216  16,099  3 cand.
#
# line 652: Ingapu-1 (Ayeyarwady)
# 68,286  53,605  45,596  5 cand.
#
# line 656: Ingapu-2 (Ayeyarwady)
# 72,094  54,990  46,665  4 cand.
#
# line 665: Myanaung-1 (Ayeyarwady)
# 67,881  49,245  42,629  3 cand.
#
# line 669: Myanaung-2 (Ayeyarwady)
# 71,909  52,025  44,311  4 cand.
#
# line 673: Laymyethnar-1 (Ayeyarwady)
# 32,595  25,403  22,003  3 cand.
#
# line 677: Laymyethnar-2 (Ayeyarwady)
# 30,509  24,835  22,717  3 cand.
#
# line 682: Kyangin (Ayeyarwady)
# 61,635  46,970  36,620  3 cand.
#
# line 686: Thaton-1 (Mon)
# 59,033  36,755  32,815  5 cand.
#
# line 691: Pauktaw-1 (Rakhine)
# 31,257  20,294  15,356  4 cand.
#
# line 701: Pauktaw-2 (Rakhine)
# 29,819  15,376  10,857  6 cand.
#
# line 713: Ponnagyun (Rakhine)
# 54,968  44,396  37,311  6 cand.
#
# line 721: Myitkyina-1 (Kachin)
# 39,204  26,003  21,837  6 cand.
#
# line 729: Myitkyina-2 (Kachin)
# 39,894  22,420  19,244  6 cand.
#
# line 738: Mohnyin-2 (Kachin)
# 27,468  19,520  16,940  4 cand.
#
# line 746: Tanai (Kachin)
# 8,917  4,876  4,319  5 cand.
#
# line 750: Lewe-1 (Mandalay)
# 58,837  47,469  42,405  4 cand.
#
# line 755: Lewe-2 (Mandalay)
# 59,952  47,560  41,923  4 cand.
#
# line 759: Pyinmanaa-1 (Mandalay)
# 67,814  51,240  44,935  3 cand.
#
# line 763: Pyinmanaa-2 (Mandalay)
# 72,283  53,218  48,082  7 cand.
#
# line 767: Singu (Mandalay)
# 53,674  43,454  41,568  5 cand.
#
# line 771: Kyaukse-1 (Mandalay)
# 48,534  40,018  35,479  4 cand.
#
# line 776: Kyaukse-2 (Mandalay)
# 47,027  39,174  34,394  5 cand.
#
# line 780: Tada-U-1 (Mandalay)
# 37,804  28,712  24,942  4 cand.
#
# line 784: Tada-U-2 (Mandalay)
# 37,967  30,525  25,897  5 cand.
#
# line 788: Singaing-1 (Mandalay)
# 31,808  27,285  24,641  6 cand.
#
# line 792: Singaing-2 (Mandalay)
# 29,359  24,802  22,379  6 cand.
#
# line 797: Myittha-1 (Mandalay)
# 40,971  34,695  29,520  6 cand.
#
# line 801: Myittha-2 (Mandalay)
# 42,882  35,283  29,741  7 cand.
#
# line 806: Bogale-1 (Ayeyarwady)
# 83,906  45,958  38,608  3 cand.
#
# line 810: Bogale-2 (Ayeyarwady)
# 89,656  58,635  52,045  3 cand.
#
# line 814: Magway-1 (Magway)
# 73,001  51,016  47,536  6 cand.
#
# line 818: Magway-2 (Magway)
# 72,654  51,533  46,910  5 cand.
#
# line 822: Chauk-1 (Magway)
# 58,464  43,366  38,181  8 cand.
#
# line 826: Chauk-2 (Magway)
# 58,727  43,437  38,047  3 cand.
#
# line 831: Myothit-1 (Magway)
# 37,313  24,478  21,136  4 cand.
#
# line 836: Myothit-2 (Magway)
# 36,715  26,679  22,409  3 cand.
#
# line 841: Hpa-an-1 (Kayin)
# 56,084  30,566  25,489  5 cand.
#
# line 846: Hpa-an-2 (Kayin)
# 54,177  34,507  29,616  6 cand.
#
# line 854: Hpa-an-3 (Kayin)
# 52,590  29,737  24,983  4 cand.
#
# line 859: Kyaikto-1 (Mon)
# 39,706  28,819  24,657  3 cand.
#
# line 863: Kyaikto-2 (Mon)
# 34,295  24,767  22,244  2 cand.
#
# line 867: Paung-1 (Mon)
# 56,187  41,116  36,287  4 cand.
#
# line 875: Paung-2 (Mon)
# 57,566  41,348  35,931  4 cand.
#
# line 883: Nyaungdon-1 (Ayeyarwady)
# 52,348  38,168  32,962  4 cand.
#
# line 891: Nyaungdon-2 (Ayeyarwady)
# 50,671  35,371  28,867  5 cand.
#
# line 895: Pantanaw-1 (Ayeyarwady)
# 60,099  43,648  37,113  5 cand.
#
# line 900: Pantanaw-2 (Ayeyarwady)
# 61,192  42,204  36,113  5 cand.
#
# line 904: Zalun-1 (Ayeyarwady)
# 55,571  42,309  37,616  3 cand.
#
# line 908: Zalun-2 (Ayeyarwady)
# 54,361  43,673  38,905  4 cand.
#
# line 913: Falam-1 (Chin)
# 12,531  9,928  9,511  3 cand.
#
# line 921: Falam-2 (Chin)
# 12,501  9,899  9,454  3 cand.
#
# line 929: Wetlet-1 (Sagaing)
# 54,571  41,951  37,858  5 cand.
#
# line 934: Wetlet-2 (Sagaing)
# 55,931  43,864  39,562  5 cand.
#
# line 939: Kyunlha (Sagaing)
# 32,647  26,627  24,012  4 cand.
#
# line 944: Ye-U-1 (Sagaing)
# 32,692  25,037  22,605  4 cand.
#
# line 949: Ye-U-2 (Sagaing)
# 32,752  26,241  24,540  3 cand.
#
# line 953: Tabayin-1 (Sagaing)
# 33,332  25,118  23,819  5 cand.
#
# line 957: Tabayin-2 (Sagaing)
# 36,528  27,099  24,746  5 cand.
#
# line 961: Hakha (Chin)
# 19,528  14,995  13,907  5 cand.
#
# line 971: Thantlang (Chin)
# 25,604  20,255  19,258  5 cand.
#
# line 981: Tonzang (Chin)
# 12,899  9,923  9,582  3 cand.
#
# line 989: 2698 28%
# 18,651  13,831  13,137  4 cand.
#
# line 997: Tiddim-2 (Chin)
# 18,180  13,674  13,021  4 cand.
#
# line 1006: Daze-1 (Sagaing)
# 39,720  28,921  23,970  4 cand.
#
# line 1010: Daze-2 (Sagaing)
# 40,555  29,560  24,742  4 cand.
#
# line 1014: Kanbalu-1 (Sagaing)
# 55,029  42,683  36,681  5 cand.
#
# line 1023: Kanbalu-2 (Sagaing)
# 55,285  46,253  40,390  7 cand.
#
# line 1027: Shwebo-1 (Sagaing)
# 67,433  54,321  50,613  4 cand.
#
# line 1031: Shwebo-2 (Sagaing)
# 68,208  57,097  53,231  5 cand.
#
# line 1035: Khin-U-1 (Sagaing)
# 35,924  26,580  22,642  4 cand.
#
# line 1039: Khin-U-2 (Sagaing)
# 35,512  27,892  23,711  3 cand.
#
# line 1048: 4145 17%
# 33,672  23,528  19,857  5 cand.
#
# line 1052: Kya-in-Seikkyi-1 (Kayin)
# 11,265  3,879  2,861  2 cand.
#
# line 1057: Kya-in-Seikkyi-2 (Kayin)
# 11,157  4,424  3,563  4 cand.
#
# line 1065: Papun-1 (Kayin)
# 7,840  4,554  4,129  3 cand.
#
# line 1069: Papun-2 (Kayin)
# 2,210  897  825  2 cand.
#
# line 1073: Kawkareik-1 (Kayin)
# 30,972  22,192  18,968  4 cand.
#
# line 1077: Kawkareik-2 (Kayin)
# 34,854  24,475  21,402  4 cand.
#
# line 1085: Myawadi (Kayin)
# 8,882  6,461  5,645  3 cand.
#
# line 1089: Mahlaing-1 (Mandalay)
# 47,457  36,208  32,891  5 cand.
#
# line 1093: Mahlaing-2 (Mandalay)
# 47,296  35,018  29,389  7 cand.
#
# line 1097: Madaya-1 (Mandalay)
# 53,421  43,721  39,668  5 cand.
#
# line 1101: Madaya-2 (Mandalay)
# 44,502  37,014  33,554  6 cand.
#
# line 1105: Meiktila-1 (Mandalay)
# 89,460  65,622  56,951  6 cand.
#
# line 1111: Meiktila-2 (Mandalay)
# 82,376  53,819  46,567  5 cand.
#
# line 1116: Thazi-1 (Mandalay)
# 46,868  38,484  34,499  3 cand.
#
# line 1124: Thazi-2 (Mandalay)
# 46,564  36,372  33,130  4 cand.
#
# line 1128: Wundwin-1 (Mandalay)
# 56,395  44,474  40,552  6 cand.
#
# line 1132: Wundwin-2 (Mandalay)
# 58,081  47,263  44,486  4 cand.
#
# line 1136: Thabeikkyin (Mandalay)
# 34,787  23,071  29,835  4 cand.
#
# line 1141: Gangaw (Magway)
# 58,228  47,719  43,416  2 cand.
#
# line 1145: Pakokku-1 (Magway)
# 81,979  64,578  57,546  5 cand.
#
# line 1149: Pakokku-2 (Magway)
# 79,497  64,872  58,519  6 cand.
#
# line 1153: Yesagyo-1 (Magway)
# 65,352  49,402  44,068  4 cand.
#
# line 1157: Yesagyo-2 (Magway)
# 63,010  50,005  45,645  5 cand.
#
# line 1162: Bilin-1 (Mon)
# 42,507  27,976  23,879  4 cand.
#
# line 1166: Bilin-2 (Mon)
# 38,462  24,425  20,772  5 cand.
#
# line 1170: Ye-1 (Mon)
# 47,746  28,198  24,429  4 cand.
#
# line 1178: Ye-2 (Mon)
# 33,834  23,329  21,391  3 cand.
#
# line 1186: Mudon-1 (Mon)
# 60,187  41,916  37,794  6 cand.
#
# line 1194: Mudon-2 (Mon)
# 58,218  42,377  36,926  5 cand.
#
# line 1203: Mawlamyine-1 (Mon)
# 80,530  56,653  51,265  8 cand.
#
# line 1207: Mawlamyine-2 (Mon)
# 75,679  54,573  49,874  6 cand.
#
# line 1212: Chaungzon-1 (Mon)
# 36,762  27,043  23,272  5 cand.
#
# line 1220: Chaungzon-2 (Mon)
# 35,547  27,076  22,758  4 cand.
#
# line 1224: Ngapudaw-1 (Ayeyarwady)
# 72,615  46,740  41,265  3 cand.
#
# line 1229: Ngapudaw-2 (Ayeyarwady)
# 76,475  54,218  47,860  4 cand.
#
# line 1234: Pathein East-1 (Ayeyarwady)
# 50,597  38,637  32,770  4 cand.
#
# line 1238: Pathein East-2 (Ayeyarwady)
# 48,409  38,034  31,767  5 cand.
#
# line 1242: Pathein West-1 (Ayeyarwady)
# 76,777  56,925  48,918  5 cand.
#
# line 1246: Pathein West-2 (Ayeyarwady)
# 77,222  54,357  46,989  6 cand.
#
# line 1251: Mogok-1 (Mandalay)
# 39,535  25,348  22,814  6 cand.
#
# line 1259: Mogok-2 (Mandalay)
# 36,726  24,596  22,873  6 cand.
#
# line 1263: Pyin-Oo-Lwin-1 [Maymyo] (Mandalay)
# 38,050  26,295  23,731  5 cand.
#
# line 1271: Pyin-Oo-Lwin-2 (Mandalay)
# 39,296  27,749  22,806  8 cand.
#
# line 1276: Kawthaung (Tanintharyi)
# 26,256  13,677  11,567  5 cand.
#
# line 1280: Palaw (Tanintharyi)
# 44,726  28,745  24,965  3 cand.
#
# line 1284: Tanintharyi (Tanintharyi)
# 24,303  11,776  9,559  4 cand.
#
# line 1288: Bokepyin (Tanintharyi)
# 18,137  7,064  6,251  2 cand.
#
# line 1292: Kyunzu (Tanintharyi)
# 46,686  19,680  16,696  3 cand.
#
# line 1297: Muse-1 (Shan)
# 24,082  17,217  15,969  2 cand.
#
# line 1302: Muse-2 (Shan)
# 16,485  10,058  8,556  2 cand.
#
# line 1307: Mongyai (Shan)
# 9,323  5,489  4,385  2 cand.
#
# line 1312: Namhkam (Shan)
# 44,789  36,095  32,298  3 cand.
#
# line 1316: Tangyan-1 (Shan)
# 10,447  4,251  3,411  4 cand.
#
# line 1327: Tangyan-2 (Shan)
# 12,492  6,647  5,694  4 cand.
#
# line 1335: Kutkai-1 (Shan)
# 12,535  6,121  4,969  5 cand.
#
# line 1345: Kutkai-2 (Shan)
# 6,898  4,522  3,774  6 cand.
#
# line 1356: Kyaukme-1 (Shan)
# 39,397  23,709  18,681  4 cand.
#
# line 1366: Kyaukme-2 (Shan)
# 32,502  19,963  16,597  4 cand.
#
# line 1374: Nawnghkio (Shan)
# 53,026  38,397  33,139  4 cand.
#
# line 1383: 5074 15%
# 37,458  33,736  31,110  3 cand.
#
# line 1388: Minhla (Magway)
# 57,204  43,216  38,167  3 cand.
#
# line 1392: Sinbaungwe (Magway)
# 55,251  41,433  36,971  5 cand.
#
# line 1396: Mindon (Magway)
# 37,590  32,529  29,763  5 cand.
#
# line 1400: Kamma (Magway)
# 43,598  36,678  33,154  6 cand.
#
# line 1404: Seikphyu (Magway)
# 46,749  39,177  33,515  2 cand.
#
# line 1408: Thayet (Magway)
# 57,562  38,694  33,618  5 cand.
#
# line 1413: Pauk-1 (Magway)
# 39,413  31,955  28,308  4 cand.
#
# line 1417: Pauk-2 (Magway)
# 38,018  29,664  25,446  6 cand.
#
# line 1421: Htilin (Magway)
# 31,384  26,702  24,909  3 cand.
#
# line 1429: Myaing-1 (Magway)
# 66,391  46,265  41,988  4 cand.
#
# line 1433: Myaing-2 (Magway)
# 62,836  44,772  39,318  5 cand.
#
# line 1437: Myayde-1 (Magway)
# 52,274  34,693  30,132  5 cand.
#
# line 1441: Myayde-2 (Magway)
# 56,371  38,848  33,530  4 cand.
#
# line 1445: Taungdwingyi-1 (Magway)
# 62,422  46,560  41,143  6 cand.
#
# line 1450: Taungdwingyi-2 (Magway)
# 59,768  44,437  39,182  4 cand.
#
# line 1454: Yenangyoung-1 (Magway)
# 46,454  35,557  32,445  6 cand.
#
# line 1459: Yenangyoung-2 (Magway)
# 46,692  33,065  30,582  6 cand.
#
# line 1463: Natmauk-1 (Magway)
# 55,749  37,424  32,837  4 cand.
#
# line 1468: Natmauk-2 (Magway)
# 57,049  40,151  35,776  3 cand.
#
# line 1473: Taungup (Rakhine)
# 63,319  42,904  35,740  4 cand.
#
# line 1477: Thandwe [Sandoway] (Rakhine)
# 67,679  53,390  46,402  6 cand.
#
# line 1481: Gwa (Rakhine)
# 36,589  27,363  22,461  4 cand.
#
# line 1485: Buthidaung-1 (Rakhine)
# 58,449  46,065  41,668  7 cand.
#
# line 1493: Buthidaung-2 (Rakine)
# 55,095  46,037  40,143  8 cand.
#
# line 1503: Htigyaint (Sagaing)
# 46,214  38,045  33,589  5 cand.
#
# line 1507: Katha (Sagaing)
# 59,103  42,719  36,538  4 cand.
#
# line 1511: Kawlin (Sagaing)
# 60,907  46,519  41,023  4 cand.
#
# line 1515: Wuntho (Sagaing)
# 33,008  26,379  21,464  3 cand.
#
# line 1519: Banmauk (Sagaing)
# 37,453  26,251  22,979  3 cand.
#
# line 1527: Indaw (Sagaing)
# 50,067  39,945  35,129  4 cand.
#
# line 1531: Pinlebu (Sagaing)
# 47,980  39,776  35,075  4 cand.
#
# line 1535: Hsipaw-1 (Shan)
# 18,139  12,233  10,577  3 cand.
#
# line 1543: Hsipaw-2 (Shan)
# 13,423  9,461  8,412  3 cand.
#
# line 1551: Namhsan (Shan)
# 19,346  10,914  9,534  3 cand.
#
# line 1559: Momeik (Shan)
# 28,799  20,929  17,253  5 cand.
#
# line 1567: Namtu (Shan)
# 32,696  20,133  17,838  4 cand.
#
# line 1575: Mabein (Shan)
# 13,401  11,547  10,514  3 cand.
#
# line 1579: Namsang (Shan)
# 20,941  11,428  9,736  3 cand.
#
# line 1589: 2641 27%
# 58,576  51,009  45,209  3 cand.
#
# line 1593: Yekyi-2 (Ayeyarwady)
# 61,340  46,133  39,879  4 cand.
#
# line 1597: Mawlamyinegyunn-1 (Ayeyarwady)
# 72,418  53,247  47,069  4 cand.
#
# line 1601: Mawlamyinegyunn-2 (Ayeyarwady)
# 70,457  45,352  39,215  5 cand.
#
# line 1605: Myaungmya-1 (Ayeyarwady)
# 84,757  61,112  51,575  5 cand.
#
# line 1609: Myaungmya-2 (Ayeyarwady)
# 86,526  55,724  45,444  4 cand.
#
# line 1614: Kyonpyaw-1 (Ayeyarwady)
# 66,058  50,523  43,508  5 cand.
#
# line 1618: Kyonpyaw-2 (Ayeyarwady)
# 63,678  51,579  44,929  4 cand.
#
# line 1623: Danubyu-1 (Ayeyarwady)
# 50,953  41,659  36,689  4 cand.
#
# line 1627: Danubyu-2 (Ayeyarwady)
# 52,825  43,031  38,258  4 cand.
#
# line 1631: Einme-1 (Ayeyarwady)
# 45,061  37,068  31,128  3 cand.
#
# line 1635: Einme-2 (Ayeyarwady)
# 44,901  36,899  30,770  4 cand.
#
# line 1639: Kyaunggon-1 (Ayeyarwady)
# 39,570  32,492  26,927  3 cand.
#
# line 1644: Kyaunggon-2 (Ayeyarwady)
# 40,796  33,695  29,205  3 cand.
#
# line 1648: Labutta-1 (Ayeyarwady)
# 75,963  43,483  35,135  4 cand.
#
# line 1652: Labutta-2 (Ayeyarwady)
# 71,279  42,641  34,627  2 cand.
#
# line 1657: Hinthada-1 (Ayeyarwady)
# 107,098  83,129  67,704  4 cand.
#
# line 1665: Hinthada-2 (Ayeyarwady)
# 100,149  80,853  71,345  4 cand.
#
# line 1669: Thabaung-1 (Ayeyarwady)
# 40,777  30,715  25,022  4 cand.
#
# line 1673: Thabaung-2 (Ayeyarwady)
# 40,658  31,079  26,545  2 cand.
#
# line 1677: Wakema-1 (Ayeyarwady)
# 79,490  56,878  49,030  4 cand.
#
# line 1682: Ramree (Rakhine)
# 59,883  42,095  35,656  5 cand.
#
# line 1687: Manaung (Rakhine)
# 42,170  32,996  27,161  6 cand.
#
# line 1691: Kyaukpyu-1 (Rakhine)
# 38,660  26,831  21,834  5 cand.
#
# line 1699: Kyaukpyu-2 (Rakhine)
# 39,697  27,439  20,958  4 cand.
#
# line 1707: Mongshu (Shan)
# 21,294  10,221  8,465  3 cand.
#
# line 1712: Kehsi (Shan)
# 28,015  9,173  7,364  3 cand.
#
# line 1717: Kunhing (Shan)
# 14,305  7,231  6,179  2 cand.
#
# line 1722: Leikha (Shan)
# 22,266  12,480  10,680  2 cand.
#
# line 1727: Loilem (Shan)
# 46,006  24,400  18,059  5 cand.
#
# line 1737: Lankho (Shan)
# 18,141  13,243  10,598  2 cand.
#
# line 1742: Mongkai (Shan)
# 24,541  15,652  13,544  2 cand.
#
# line 1747: Mongyawn (Shan)
# 15,557  5,889  3,818  3 cand.
#
# line 1751: Tachilek (Shan)
# 51,351  17,681  14,148  4 cand.
#
# line 1759: Monghpyat (Shan)
# 10,063  5,585  4,227  4 cand.
#
# line 1767: Mongping (Shan)
# 27,457  14,470  11,728  3 cand.
#
# line 1776: Mongton (Shan)
# 7,958  4,374  3,567  3 cand.
#
# line 1785: Monghsat (Shan)
# 16,807  6,962  5,092  3 cand.
#
# line 1793: Maukmai (Shan)
# 5,557  3,838  3,024  2 cand.
#
# line 1798: Mongpang (Shan)
# 4,789  3,422  3,007  2 cand.
#
# line 1803: Mongnai (Shan)
# 8,575  6,254  5,343  3 cand.
#
# line 1812: 527 10%
# 33,390  23,765  20,734  4 cand.
#
# line 1820: Homalin-2 (Sagaing)
# 32,012  19,120  16,427  5 cand.
#
# line 1828: Hkamti (Sagaing)
# 13,701  8,200  7,145  3 cand.
#
# line 1836: Waingmaw (Kachin)
# 35,741  24,792  21,751 8 cand.
#
# line 1848: 2080 10%
# 56,212  36,124  29,407  7 cand.
#
# line 1856: Phaungpyin (Sagaing)
# 37,956  33,566  28,841  3 cand.
#
# line 1860: Mawlaik (Sagaing)
# 22,327  19,230  17,663  2 cand.
#
# line 1864: Kale-1 (Sagaing)
# 62,820  44,272  40,599  6 cand.
#
# line 1874: Kale-2 (Sagaing)
# 58,991  44,117  40,307  5 cand.
#
# line 1882: Tamu (Sagaing)
# 37,680  28,783  25,281  4 cand.
#
# line 1890: Kalewa (Sagaing)
# 26,230  23,115  19,712  4 cand.
#
# line 1894: Mingin (Sagaing)
# 47,015  38,294  33,296  4 cand.
#
# line 1898: Matupi-1 (Chin)
# 12,617  10,949  10,107  6 cand.
#
# line 1908: Matupi-2 (Chin)
# 12,234  9,753  9,298  5 cand.
#
# line 1916: Paletwa-1 (Chin)
# 19,345  11,451  10,374  4 cand.
#
# line 1926: Paletwa-2 (Chin)
# 18,828  9,466  8,707  5 cand.
#
# line 1936: Kanpetlet (Chin)
# 8,201  6,820  6,430  4 cand.
#
# line 1946: Mindat (Chin)
# 17,479  14,242  13,167  4 cand.
#
# line 1955: 3186 24%
# 48,809  35,172  27,620  7 cand.
#
# line 1965: Kyauktaw-2 (Rakhine)
# 49307  36,757  28,500  5 cand.
#
# line 1973: Rathedaung-1 (Rakhine)
# 35,108  25,118  19,626  5 cand.
#
# line 1983: Rathedaung-2 (Rakhine)
# 33,843  23,629  18,910  6 cand.
#
# line 1991: Mrauk-U-1 (Rakhine)
# 43,550  33,173  27,900  5 cand.
#
# line 1997: Mrauk-U-2
# 44,524  32,026  27,200  6 cand.
#
# line 2007: Myebon (Rakhine)
# 45,361  31,221  25,031  4 cand.
#
# line 2015: An (Rakhine)
# 46,770  26,081  19,945  4 cand.
#
# line 2024: 2121 11%
# 1,284  879  806  2 cand.
#
# line 2029: Khawbude (Kachin)
# 5,997  3,381  3,180  4 cand.
#
# line 2037: Machambaw (Kachin)
# 6,138  4,604  4,082  4 cand.
#
# line 2045: Kamaing (Kachin)
# 11,327  5,755  5,208  6 cand.
#
# line 2053: Putao (Kachin)
# 29,900  21,960  17,707  8 cand.
#
# line 2061: Nogmun (Kachin)
# 3,850  3,096  2,877  3 cand.
#
# line 2065: Maungdaw-1 (Rakhine)
# 87,174  73,633  64,019  7 cand.
#
# line 2075: Maungdaw-2 (Rakhine)
# 84,166  68,440  58,230  7 cand.
#
# line 2086: 2221  4%
# 8,847  5,511  4,678  3 cand.
#
# line 2095: 115  2%
# 5,572  4,951  4,724  2 cand.
#
# line 2101: Chipwe (Kachin)
# 1,753  1,417  1,339  3 cand.
#
# line 2107: Hsawlaw (Kachin)
# 452  397  382  4 cand.

# %% [markdown]
# ## Clean Constituency Names and Total Vote Counts

# %%
for (i,line) in enumerate(lines):
    if "cand." in line and "(" not in lines[i-1]:
        print("\nline " + str(i-1) + ": " + lines[i-1] + '\n' + ' '.join('{}'.format(k) for k in line.split(";")))
# Out:
# line 116: Zigon {Bago)
# 41,957  33,429  28,158  5 cand.
#
# line 125: 35,260; 23,568; [not given, but valid votes tallied equal votes
# cast]  5 cand.
#
# line 141: 648 10%
# 77,887  62,961  57,674  7 cand.
#
# line 404: 3081 13%
# 42,114  28,353  24,086  4 cand.
#
# line 601: 2547  8%
# 59,033  36,755  32,815  5 cand.
#
# line 989: 2698 28%
# 18,651  13,831  13,137  4 cand.
#
# line 1048: 4145 17%
# 33,672  23,528  19,857  5 cand.
#
# line 1383: 5074 15%
# 37,458  33,736  31,110  3 cand.
#
# line 1589: 2641 27%
# 58,576  51,009  45,209  3 cand.
#
# line 1812: 527 10%
# 33,390  23,765  20,734  4 cand.
#
# line 1848: 2080 10%
# 56,212  36,124  29,407  7 cand.
#
# line 1955: 3186 24%
# 48,809  35,172  27,620  7 cand.
#
# line 1997: Mrauk-U-2
# 44,524  32,026  27,200  6 cand.
#
# line 2024: 2121 11%
# 1,284  879  806  2 cand.
#
# line 2086: 2221  4%
# 8,847  5,511  4,678  3 cand.
#
# line 2095: 115  2%
# 5,572  4,951  4,724  2 cand.

# %% [markdown]
# Looks like everything is well formed except lines 116, 125, 141, 404, 601, 989, 1048, 1383, 1589, 1812, 1848, 1955, 1997, 2024, 2086 and 2095

# %%
inserted_lines = 0

# %%
lines[116] = lines[116].replace("{","()")

# %%
print(lines[125])
print(lines[126])

lines[125] = lines[125].strip() + lines[126].strip()
print(lines[125])

new_arr = lines[125].split("; ")

## In this constituency, valid votes equaled to votes cast
new_arr[2] = new_arr[1]
lines[125] = "; ".join(new_arr)
print(lines[125])
print(lines[126])

## Remove the dangling line
lines.pop(126 + inserted_lines)
#inserted_lines -= 1
# Out:
# 35,260; 23,568; [not given, but valid votes tallied equal votes
# cast]; 5 cand.
# 35,260; 23,568; [not given, but valid votes tallied equal votescast]; 5 cand.
# 35,260; 23,568; 23,568; 5 cand.
# cast]; 5 cand.
# 'cast]; 5 cand.'

# %%
## For these rows the constituency name is misplaced a few lines above the vote counts instead of right above
lines.insert(141+inserted_lines,"Sagaing-2 (Sagaing)")
inserted_lines += 1
lines.insert(404+inserted_lines,"Thegon-1 (Bago)")
inserted_lines += 1
lines.insert(601+inserted_lines,"Thaton-1 (Mon)")
inserted_lines += 1
lines.insert(989+inserted_lines,"Tiddim-1 (Chin)")
inserted_lines += 1
lines.insert(1048+inserted_lines,"Gyobingauk-2 (Bago)")
inserted_lines += 1
lines.insert(1383+inserted_lines,"Saw (Magway)")
inserted_lines += 1
lines.insert(1589+inserted_lines,"Yekyi-1 (Ayeyarwady)")
inserted_lines += 1
lines.insert(1812+inserted_lines,"Homalin-1 (Sagaing)")
inserted_lines += 1
lines.insert(1848+inserted_lines,"Mogaung (Kachin)")
inserted_lines += 1
lines.insert(1955+inserted_lines,"Kyauktaw-1 (Rakhine)")
inserted_lines += 1
lines[1997+inserted_lines-1] = "Mrauk-U-2 (Rakhine)"
lines.insert(2024+inserted_lines,"Sumprabum (Kachin)")
inserted_lines += 1
lines.insert(2086+inserted_lines,"Lahe (Sagaing)")
inserted_lines += 1
lines.insert(2095+inserted_lines,"Leshi (Sagaing)")

# %% [markdown]
# ## Put constituency names and vote counts in a dataframe

# %%
consti_df = pd.DataFrame(columns=['line','constituency','state','eligible_voters','votes_cast','valid_votes','num_candidates'])

# %%
for (i,line) in enumerate(lines):
    line = line.strip()
    if "cand." in line:
        prev_line = lines[i-1].strip()
        [constituency,state] = prev_line.split('(')
        constituency = constituency.strip()
        state = state.replace(')','').strip()
        [eligible_voters,votes_cast,valid_votes,num_candidates] = map(int,line.replace('cand.','') \
                    .replace(',','').replace(' ','').split(";"))
        #print(constituency + ", " + state + ", " + str(eligible_voters) + ", " \
        #      + str(votes_cast) + ", " + str(valid_votes) + ", " + str(num_candidates))
        d = {'line': i, \
             'constituency' : [constituency], \
             'state' : [state], \
             'eligible_voters' : [eligible_voters], \
             'votes_cast' : [votes_cast], \
             'valid_votes' : [valid_votes], \
             'num_candidates' : [num_candidates]}
        consti_df = consti_df.append(pd.DataFrame(data=d))
    
consti_df = consti_df.reset_index()
consti_df.drop(['index'], axis = 1, inplace=True)
consti_df
# Out:
#               constituency  eligible_voters    line  num_candidates  \
# 0                  Kayan-1          41226.0     1.0             4.0
# 1                  Kayan-2          40018.0     5.0             6.0
# 2                 Wakema-2          72831.0     9.0             4.0
# 3    Mandalay North East-1          37046.0    18.0             8.0
# 4                  Minbu-1          43600.0    22.0             6.0
# 5                  Minbu-2          42102.0    26.0             3.0
# 6    Mandalay North West-2          50451.0    31.0             6.0
# 7                   Ngaphe          21337.0    35.0             3.0
# 8    Mandalay North East-2          38885.0    39.0             6.0
# 9               Kunyangonn          56590.0    43.0             6.0
# 10            Patheingyi-1          36244.0    47.0             6.0
# 11            Patheingyi-2          34087.0    51.0             7.0
# 12              Kyaiklat-1          45458.0    56.0             4.0
# 13              Kyaiklat-2          46027.0    60.0             4.0
# 14                Pyapon-2          52684.0    64.0             5.0
# 15                Dedaye-2          52412.0    68.0             6.0
# 16              Nattalin-1          47418.0    72.0             4.0
# 17              Nattalin-2          48088.0    76.0             5.0
# 18             Amarapura-1          42741.0    80.0             6.0
# 19             Amarapura-2          43735.0    84.0             5.0
# 20                 Hlegu-1          79523.0    89.0             4.0
# 21                 Hlegu-2          30784.0    93.0             5.0
# 22              Kyauktan-1          37399.0    97.0             4.0
# 23              Kyauktan-2          34840.0   101.0             3.0
# 24            Kyobingauk-1          35256.0   105.0             5.0
# 25                  Okpo-1          34368.0   109.0             6.0
# 26                  Okpo-2          39086.0   113.0             7.0
# 27                   Zigon          41957.0   117.0             5.0
# 28                Minhla-1          36120.0   121.0             5.0
# 29                Minhla-2          35260.0   125.0             5.0
# ..                     ...              ...     ...             ...
# 349                 Kale-2          58991.0  1883.0             5.0
# 350                   Tamu          37680.0  1891.0             4.0
# 351                 Kalewa          26230.0  1899.0             4.0
# 352                 Mingin          47015.0  1903.0             4.0
# 353               Matupi-1          12617.0  1907.0             6.0
# 354               Matupi-2          12234.0  1917.0             5.0
# 355              Paletwa-1          19345.0  1925.0             4.0
# 356              Paletwa-2          18828.0  1935.0             5.0
# 357              Kanpetlet           8201.0  1945.0             4.0
# 358                 Mindat          17479.0  1955.0             4.0
# 359             Kyauktaw-1          48809.0  1965.0             7.0
# 360             Kyauktaw-2          49307.0  1975.0             5.0
# 361           Rathedaung-1          35108.0  1983.0             5.0
# 362           Rathedaung-2          33843.0  1993.0             6.0
# 363              Mrauk-U-1          43550.0  2001.0             5.0
# 364              Mrauk-U-2          44524.0  2007.0             6.0
# 365                 Myebon          45361.0  2017.0             4.0
# 366                     An          46770.0  2025.0             4.0
# 367              Sumprabum           1284.0  2035.0             2.0
# 368               Khawbude           5997.0  2040.0             4.0
# 369              Machambaw           6138.0  2048.0             4.0
# 370                Kamaing          11327.0  2056.0             6.0
# 371                  Putao          29900.0  2064.0             8.0
# 372                 Nogmun           3850.0  2072.0             3.0
# 373             Maungdaw-1          87174.0  2076.0             7.0
# 374             Maungdaw-2          84166.0  2086.0             7.0
# 375                   Lahe           8847.0  2098.0             3.0
# 376                  Leshi           5572.0  2108.0             2.0
# 377                 Chipwe           1753.0  2114.0             3.0
# 378                Hsawlaw            452.0  2120.0             4.0
#
#           state  valid_votes  votes_cast
# 0        Yangon      31328.0     33996.0
# 1        Yangon      28841.0     32524.0
# 2    Ayeyarwady      41528.0     49584.0
# 3      Mandalay      29005.0     30833.0
# 4        Magway      28506.0     31928.0
# 5        Magway      24456.0     28063.0
# 6      Mandalay      35234.0    380943.0
# 7        Magway      15107.0     17077.0
# 8      Mandalay      29401.0     30746.0
# 9        Yangon      42287.0     47680.0
# 10     Mandalay      24662.0     27769.0
# 11     Mandalay      24014.0     27070.0
# 12   Ayeyarwady      30873.0     35056.0
# 13   Ayeyarwady      29710.0     33590.0
# 14   Ayeyarwady      31864.0     34758.0
# 15   Ayeyarwady      34384.0     39577.0
# 16         Bago      33017.0     38764.0
# 17         Bago      32112.0     37488.0
# 18     Mandalay      31829.0     34831.0
# 19     Mandalay      35226.0     37185.0
# 20       Yangon      45831.0     54235.0
# 21       Yangon      20344.0     23143.0
# 22       Yangon      26200.0     31668.0
# 23       Yangon      24602.0     28169.0
# 24         Bago      21079.0     25007.0
# 25         Bago      19700.0     23523.0
# 26         Bago      22873.0     26435.0
# 27         Bago      28158.0     33429.0
# 28         Bago      24366.0     27489.0
# 29         Bago      23568.0     23568.0
# ..          ...          ...         ...
# 349     Sagaing      40307.0     44117.0
# 350     Sagaing      25281.0     28783.0
# 351     Sagaing      19712.0     23115.0
# 352     Sagaing      33296.0     38294.0
# 353        Chin      10107.0     10949.0
# 354        Chin       9298.0      9753.0
# 355        Chin      10374.0     11451.0
# 356        Chin       8707.0      9466.0
# 357        Chin       6430.0      6820.0
# 358        Chin      13167.0     14242.0
# 359     Rakhine      27620.0     35172.0
# 360     Rakhine      28500.0     36757.0
# 361     Rakhine      19626.0     25118.0
# 362     Rakhine      18910.0     23629.0
# 363     Rakhine      27900.0     33173.0
# 364     Rakhine      27200.0     32026.0
# 365     Rakhine      25031.0     31221.0
# 366     Rakhine      19945.0     26081.0
# 367      Kachin        806.0       879.0
# 368      Kachin       3180.0      3381.0
# 369      Kachin       4082.0      4604.0
# 370      Kachin       5208.0      5755.0
# 371      Kachin      17707.0     21960.0
# 372      Kachin       2877.0      3096.0
# 373     Rakhine      64019.0     73633.0
# 374     Rakhine      58230.0     68440.0
# 375     Sagaing       4678.0      5511.0
# 376     Sagaing       4724.0      4951.0
# 377      Kachin       1339.0      1417.0
# 378      Kachin        382.0       397.0
#
# [379 rows x 7 columns]

# %% [markdown]
# ## Loop through again to add candidate vote counts

# %%
def parse_candidates_lines(lines_to_parse):
    return_list = []
    for l in lines_to_parse:
        #l = lines_to_parse[i]
        candidate = ''
        party = ''
        votes = ''
        percent = ''
        
        regex_candidate = r"(.*)\s+\((.*)\)"
        regex_candidate_1 = r"([a-zA-Z- ]+)"
        regex_vote = r"(\d+)\s+(\d+)%"
        
        candidate_capture = re.findall(regex_candidate, l)
        if len(candidate_capture) > 0:
            candidate = candidate_capture[0][0]
            party = candidate_capture[0][1]
        else:
            candidate_capture_1 = re.findall(regex_candidate_1, l)
            if len(candidate_capture_1) > 0 and len(candidate_capture_1[0].strip()):
                candidate = candidate_capture_1[0]
                party = 'Unknown'
            
        
        vote_capture = re.findall(regex_vote, l)
        if len(vote_capture) > 0:
            votes = vote_capture[0][0]
            percent = vote_capture[0][1]
        
        #print('{}, {}, {}, {}'.format(candidate,party,votes,percent))
        return_list.append({'candidate' : candidate.strip(), \
                            'party' : party.strip(), \
                            'votes' : votes.strip(), \
                            'percent' : percent.strip()})
    return return_list

# %%
def get_structured_candidates_votes(candidates_votes_list,constituency):
    
    candidates = []
    parties = []
    votes = []
    percents = []
    
    rows_to_remove = []
    
    # prioritise parsing complete rows
    for i,l in enumerate(candidates_votes_list):
        if l['candidate'] != '' and l['party'] != '' and l['votes'] != '' and l['percent'] != '':
            candidates.append(l['candidate'])
            parties.append(l['party'])
            votes.append(l['votes'])
            percents.append(l['percent'])
            rows_to_remove.append(i)
    
        
    temp_list = [x for i,x in enumerate(candidates_votes_list) if i not in rows_to_remove] 
    candidates_votes_list = temp_list
    
    # now add the non-complete rows
    for l in candidates_votes_list:
        if l['candidate'] != '':
            candidates.append(l['candidate'])
        if l['party'] != '':
            parties.append(l['party'])
        if l['votes'] != '':
            votes.append(l['votes'])
        if l['percent'] != '':
            percents.append(l['percent'])
            
    maxlength = min([len(candidates),len(parties),len(votes),len(percents)])
    candidates = candidates[0:maxlength]
    parties = parties[0:maxlength]
    votes = votes[0:maxlength]
    percents = percents[0:maxlength]
    constituencies = [constituency]*(maxlength)
    
    to_return = pd.DataFrame(data={'candidate': candidates, 'party' : parties, \
                                   'votes' : votes, 'percent' : percents, 'constituency': constituencies})
    #print(to_return)
    
    return to_return

# %%
candidates_df = pd.DataFrame(columns=['constituency','eligible_voters','line', \
                'num_candidates','state','valid_votes','votes_cast','candidate', \
                'party','percent','votes'])

for index, row in consti_df.iterrows():
    #print(index)
    
    # if not at last 2 rows
    if index < consti_df.index.size - 2:
        lines_to_parse = lines[ int(row['line']) + 1 : int(consti_df.iloc[index+1]['line']) - 1 ] 
        #print(lines_to_parse)
        d = parse_candidates_lines(lines_to_parse)
        df_to_append = get_structured_candidates_votes(d,row['constituency'])
        
    # last 2 constituencies results are not well formatted
    elif index == consti_df.index.size - 2:
        lines_to_parse = lines[ int(row['line']) + 1 : int(consti_df.iloc[index+1]['line']) + 4 ]
        #print(lines_to_parse)
        d = parse_candidates_lines(lines_to_parse)
        df_to_append = get_structured_candidates_votes(d,row['constituency'])
    else:
        lines_to_parse = lines[ int(row['line']) + 4 : len(lines) - 1 ]
        #print(lines_to_parse)
        d = parse_candidates_lines(lines_to_parse)
        df_to_append = get_structured_candidates_votes(d,row['constituency'])
     
    temp_df = pd.DataFrame(data = row).transpose()
    temp_df = pd.merge(temp_df,df_to_append,on='constituency',how='inner')
    candidates_df = candidates_df.append(temp_df)
    #print(temp_df)
    
candidates_df
# Out:
#   constituency eligible_voters line num_candidates   state valid_votes  \
# 0      Kayan-1           41226    1              4  Yangon       31328
# 1      Kayan-1           41226    1              4  Yangon       31328
#
#   votes_cast   candidate party percent  votes
# 0      33996  Kyaw Thwin   NLD      68  21278
# 1      33996  Than Maung   NUP      27   8408
#   constituency eligible_voters line num_candidates   state valid_votes  \
# 0      Kayan-2           40018    5              6  Yangon       28841
# 1      Kayan-2           40018    5              6  Yangon       28841
#
#   votes_cast      candidate party percent  votes
# 0      32524  Tin Maung Win   NLD      60  17428
# 1      32524        Zaw Win   NUP      35  10027
#   constituency eligible_voters line num_candidates       state valid_votes  \
# 0     Wakema-2           72831    9              4  Ayeyarwady       41528
# 1     Wakema-2           72831    9              4  Ayeyarwady       41528
# 2     Wakema-2           72831    9              4  Ayeyarwady       41528
#
#   votes_cast         candidate party percent  votes
# 0      49584     Col. Thet Wai   NUP      43  17893
# 1      49584         Myint Swe   LDP      30  12307
# 2      49584  Dr. Saw Bei Htoo   UKL      23   9629
#             constituency eligible_voters line num_candidates     state  \
# 0  Mandalay North East-1           37046   18              8  Mandalay
# 1  Mandalay North East-1           37046   18              8  Mandalay
#
#   valid_votes votes_cast        candidate party percent  votes
# 0       29005      30833  Maung Maung Aye   NLD      83  24100
# 1       29005      30833         Kyaw Aye   WUO      10   2822
#   constituency eligible_voters line num_candidates   state valid_votes  \
# 0      Minbu-1           43600   22              6  Magway       28506
# 1      Minbu-1           43600   22              6  Magway       28506
#
#   votes_cast       candidate party percent  votes
# 0      31928       Soe Myint   NLD      75  21324
# 1      31928  Col. Kyi Thein   WUO      20   5685
#   constituency eligible_voters line num_candidates   state valid_votes  \
# 0      Minbu-2           42102   26              3  Magway       24456
# 1      Minbu-2           42102   26              3  Magway       24456
#
#   votes_cast candidate    party percent  votes
# 0      28063   Hla Soe      NLD      85  20719
# 1      28063       Win  LDP-141      11   2621
#             constituency eligible_voters line num_candidates     state  \
# 0  Mandalay North West-2           50451   31              6  Mandalay
# 1  Mandalay North West-2           50451   31              6  Mandalay
#
#   valid_votes votes_cast     candidate party percent  votes
# 0       35234     380943      Aung Soe   NLD      67  23576
# 1       35234     380943  Col. Chit Yi   NUP      31  10782
#   constituency eligible_voters line num_candidates   state valid_votes  \
# 0       Ngaphe           21337   35              3  Magway       15107
# 1       Ngaphe           21337   35              3  Magway       15107
#
#   votes_cast candidate party percent  votes
# 0      17077  Kyi Lwin   NLD      72  10807
# 1      17077  Tin Sein   NUP      26   3945
#             constituency eligible_voters line num_candidates     state  \
# 0  Mandalay North East-2           38885   39              6  Mandalay
# 1  Mandalay North East-2           38885   39              6  Mandalay
#
#   valid_votes votes_cast  candidate party percent  votes
# 0       29401      30746    Tin Aye   NLD      77  22547
# 1       29401      30746  Tin Maung   NUP      16   4621
#   constituency eligible_voters line num_candidates   state valid_votes  \
# 0   Kunyangonn           56590   43              6  Yangon       42287
# 1   Kunyangonn           56590   43              6  Yangon       42287
#
#   votes_cast   candidate party percent  votes
# 0      47680         Gun   NLD      67  28198
# 1      47680  Kyaw Nyunt   NUP      25  10763
#    constituency eligible_voters line num_candidates     state valid_votes  \
# 0  Patheingyi-1           36244   47              6  Mandalay       24662
# 1  Patheingyi-1           36244   47              6  Mandalay       24662
#
#   votes_cast        candidate party percent  votes
# 0      27769  Hsan Nyunt Wain   NLD      66  16336
# 1      27769          Tun Kyi   NUP      29   7206
#    constituency eligible_voters line num_candidates     state valid_votes  \
# 0  Patheingyi-2           34087   51              7  Mandalay       24014
# 1  Patheingyi-2           34087   51              7  Mandalay       24014
# 2  Patheingyi-2           34087   51              7  Mandalay       24014
#
#   votes_cast           candidate        party percent  votes
# 0      27070  Lt-Col San Hla Baw          NLD      58  13870
# 1      27070              Kyaung          PUO      27   6587
# 2      27070           Naing Win  independent      11   2732
#   constituency eligible_voters line num_candidates       state valid_votes  \
# 0   Kyaiklat-1           45458   56              4  Ayeyarwady       30873
# 1   Kyaiklat-1           45458   56              4  Ayeyarwady       30873
#
#   votes_cast  candidate party percent  votes
# 0      35056   Than Tin   NLD      53  16451
# 1      35056  Maung Mya   NUP      41  12596
#   constituency eligible_voters line num_candidates       state valid_votes  \
# 0   Kyaiklat-2           46027   60              4  Ayeyarwady       29710
# 1   Kyaiklat-2           46027   60              4  Ayeyarwady       29710
#
#   votes_cast        candidate party percent  votes
# 0      33590          Tin Win   NLD      48  14351
# 1      33590  Saw Myint Thein   NUP      43  12774
#   constituency eligible_voters line num_candidates       state valid_votes  \
# 0     Pyapon-2           52684   64              5  Ayeyarwady       31864
# 1     Pyapon-2           52684   64              5  Ayeyarwady       31864
#
#   votes_cast candidate party percent  votes
# 0      34758   Min Swe   NLD      64  20358
# 1      34758    Aye Ko   PUO      33  10404
#   constituency eligible_voters line num_candidates       state valid_votes  \
# 0     Dedaye-2           52412   68              6  Ayeyarwady       34384
# 1     Dedaye-2           52412   68              6  Ayeyarwady       34384
#
#   votes_cast    candidate party percent  votes
# 0      39577     Than Tun   NLD      57  19612
# 1      39577  Nyunt Maung   NUP      33  11368
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0   Nattalin-1           47418   72              4  Bago       33017
# 1   Nattalin-1           47418   72              4  Bago       33017
#
#   votes_cast      candidate party percent  votes
# 0      38764       Ohn Ngwe   NLD      74  24388
# 1      38764  Daw Aye Myint   PUO      23   7646
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0   Nattalin-2           48088   76              5  Bago       32112
# 1   Nattalin-2           48088   76              5  Bago       32112
#
#   votes_cast     candidate party percent  votes
# 0      37488  Saw Sein Tun   NLD      73  23548
# 1      37488    Aung Thein   NUP      24   7581
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0  Amarapura-1           42741   80              6  Mandalay       31829
# 1  Amarapura-1           42741   80              6  Mandalay       31829
#
#   votes_cast        candidate party percent  votes
# 0      34831  Zaw Myint Maung   NLD      66  21119
# 1      34831        Thain Han   NUP      26   8210
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0  Amarapura-2           43735   84              5  Mandalay       35226
# 1  Amarapura-2           43735   84              5  Mandalay       35226
#
#   votes_cast   candidate party percent  votes
# 0      37185      Ba Bwa   NLD      69  24163
# 1      37185  Than Maung   NUP      23   8147
#   constituency eligible_voters line num_candidates   state valid_votes  \
# 0      Hlegu-1           79523   89              4  Yangon       45831
# 1      Hlegu-1           79523   89              4  Yangon       45831
#
#   votes_cast      candidate party percent  votes
# 0      54235  Saw Kyaw Sein   NLD      57  26113
# 1      54235         Ye Win   NUP      39  17815
#   constituency eligible_voters line num_candidates   state valid_votes  \
# 0      Hlegu-2           30784   93              5  Yangon       20344
# 1      Hlegu-2           30784   93              5  Yangon       20344
#
#   votes_cast       candidate party percent  votes
# 0      23143         San Tin   NLD      72  14640
# 1      23143  Daw Thein Htay   NUP      18   3719
#   constituency eligible_voters line num_candidates   state valid_votes  \
# 0   Kyauktan-1           37399   97              4  Yangon       26200
# 1   Kyauktan-1           37399   97              4  Yangon       26200
#
#   votes_cast   candidate party percent  votes
# 0      31668  Than Nyein   NLD      65  17018
# 1      31668   Thein Tun   NUP      28   7331
#   constituency eligible_voters line num_candidates   state valid_votes  \
# 0   Kyauktan-2           34840  101              3  Yangon       24602
# 1   Kyauktan-2           34840  101              3  Yangon       24602
#
#   votes_cast    candidate party percent  votes
# 0      28169    Soe Nyunt   NLD      66  16226
# 1      28169  Aung Khaing   NUP      30   7390
#    constituency eligible_voters line num_candidates state valid_votes  \
# 0  Kyobingauk-1           35256  105              5  Bago       21079
# 1  Kyobingauk-1           35256  105              5  Bago       21079
#
#   votes_cast       candidate party percent  votes
# 0      25007       Aye Myint   NLD      60  12739
# 1      25007  Khin Maung Win   NUP      33   6991
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0       Okpo-1           34368  109              6  Bago       19700
# 1       Okpo-1           34368  109              6  Bago       19700
#
#   votes_cast candidate party percent  votes
# 0      23523    Tin Oo   NLD      52  10166
# 1      23523    Mar Ga   PUO      33   6434
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0       Okpo-2           39086  113              7  Bago       22873
# 1       Okpo-2           39086  113              7  Bago       22873
#
#   votes_cast  candidate party percent  votes
# 0      26435  Tha Maung   NLD      54  12443
# 1      26435    Tin Kyi   NUP      32   7354
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0        Zigon           41957  117              5  Bago       28158
# 1        Zigon           41957  117              5  Bago       28158
#
#   votes_cast          candidate party percent  votes
# 0      33429            San Tin   NLD      57  15992
# 1      33429  Brig-Gen Than Tin   NUP      35   9943
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0     Minhla-1           36120  121              5  Bago       24366
# 1     Minhla-1           36120  121              5  Bago       24366
#
#   votes_cast        candidate party percent  votes
# 0      27489        Tint Lwin   NLD      66  16110
# 1      27489  Col. Thein Ngwe   NUP      26   6220
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0     Minhla-2           35260  125              5  Bago       23568
# 1     Minhla-2           35260  125              5  Bago       23568
#
#   votes_cast        candidate party percent  votes
# 0      23568  Daw Hla Hla Moe   NLD      69  16282
# 1      23568      Maung Maung   NUP      26   6236
#   constituency eligible_voters line num_candidates   state valid_votes  \
# 0        Bhamo           48181  129              6  Kachin       27550
# 1        Bhamo           48181  129              6  Kachin       27550
#
#   votes_cast candidate party percent  votes
# 0      32055   Pu Htwe   NLD      71  19433
# 1      32055   Kam Twe   NUP      17   4612
#   constituency eligible_voters line num_candidates   state valid_votes  \
# 0       Momauk           13104  133              6  Kachin        6501
# 1       Momauk           13104  133              6  Kachin        6501
# 2       Momauk           13104  133              6  Kachin        6501
#
#   votes_cast    candidate party percent votes
# 0       7602  Thaung Ngwe   NLD      45  2954
# 1       7602      Mo Ngin  SNLD      31  2036
# 2       7602       Po Yin   NUP      10   648
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0    Sagaing-2           77887  142              7  Sagaing       57674
# 1    Sagaing-2           77887  142              7  Sagaing       57674
#
#   votes_cast           candidate party percent  votes
# 0      62961  Dr. Khin Maung Swe   NLD      72  41523
# 1      62961          Khin Maung   NUP      24  13745
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0     Myaung-2           33485  146              5  Sagaing       24205
# 1     Myaung-2           33485  146              5  Sagaing       24205
# 2     Myaung-2           33485  146              5  Sagaing       24205
#
#   votes_cast    candidate        party percent votes
# 0      26741    Min Thwin          NLD      41  9941
# 1      26741      Zay Yar  independent      31  7612
# 2      26741  Shwe Khaing          NUP      22  5431
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0     Myinmu-1           29892  154              4  Sagaing       22545
# 1     Myinmu-1           29892  154              4  Sagaing       22545
#
#   votes_cast  candidate party percent  votes
# 0      24679      Ba Ba   NLD      73  16477
# 1      24679  Htay Aung   NUP      26   5783
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0     Myinmu-2           30935  158              3  Sagaing       22398
# 1     Myinmu-2           30935  158              3  Sagaing       22398
#
#   votes_cast candidate party percent  votes
# 0      24653  Tin Ngwe   NLD      72  16151
# 1      24653  Sein Tun   PUO      27   5944
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0     Myaung-1           33415  162              5  Sagaing       24747
# 1     Myaung-1           33415  162              5  Sagaing       24747
# 2     Myaung-1           33415  162              5  Sagaing       24747
#
#   votes_cast  candidate        party percent votes
# 0      26885  Win Shein  independent      39  9749
# 1      26885   Aung Tun          NLD      33  8175
# 2      26885  Aye Maung          NUP      25  6148
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0     Ngazun-1           39852  170              3  Sagaing       24881
# 1     Ngazun-1           39852  170              3  Sagaing       24881
#
#   votes_cast      candidate party percent  votes
# 0      28600    Chit Khaing   NLD      68  16881
# 1      28600  Khin Maung Oo   NUP      30   7355
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0    Sagaing-1           71844  174              8  Sagaing       52772
# 1    Sagaing-1           71844  174              8  Sagaing       52772
#
#   votes_cast       candidate party percent  votes
# 0      58103  Col. Soe Thein   NLD      70  37037
# 1      58103       Tun Maung   PUO      22  11653
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0     Ngazun-2           40271  178              3  Sagaing       25676
# 1     Ngazun-2           40271  178              3  Sagaing       25676
#
#   votes_cast         candidate party percent  votes
# 0      30722        Cho Hlaing   NLD      72  18480
# 1      30722  Khin Maung Maung   NUP      25   6339
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0     Kyaukkyi           43167  183              3  Bago       20343
# 1     Kyaukkyi           43167  183              3  Bago       20343
#
#   votes_cast     candidate party percent  votes
# 0      23512        Tun Oo   NLD      71  14461
# 1      23512  Saw Myo Thwe   NUP      25   5086
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0    Taungoo-1           54044  187              6  Bago       31543
# 1    Taungoo-1           54044  187              6  Bago       31543
#
#   votes_cast       candidate party percent  votes
# 0      35458  Aung Soe Myint   NLD      68  21369
# 1      35458    Thein Hlaing   NUP      20   6354
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0    Taungoo-2           55749  191              5  Bago       30405
# 1    Taungoo-2           55749  191              5  Bago       30405
#
#   votes_cast   candidate party percent  votes
# 0      36178   Nyunt Wai   NLD      67  20401
# 1      36178  Saw Truman   NUP      25   7567
#      constituency eligible_voters line num_candidates state valid_votes  \
# 0  Pyay-1 [Prome]           59592  195              7  Bago       35315
# 1  Pyay-1 [Prome]           59592  195              7  Bago       35315
# 2  Pyay-1 [Prome]           59592  195              7  Bago       35315
#
#   votes_cast           candidate  party percent  votes
# 0      40181           Maung Ohn    NUP      42  14850
# 1      40181           Thein Zan    NLD      35  12229
# 2      40181  Dr. Khin Maung Win  indep      17   6161
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0       Pyay-2           62493  200              6  Bago       36768
# 1       Pyay-2           62493  200              6  Bago       36768
#
#   votes_cast    candidate party percent  votes
# 0      40662  Thaung Sein   NLD      52  18941
# 1      40662          Soe   NUP      40  14535
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0    Paukkaung           56337  204              8  Bago       35063
# 1    Paukkaung           56337  204              8  Bago       35063
#
#   votes_cast  candidate party percent  votes
# 0      39412   Sein Win   PND      50  17511
# 1      39412  Ohn Thein   NUP      41  14448
#    constituency eligible_voters line num_candidates state valid_votes  \
# 0  Thayarwady-1           42498  209              6  Bago       27877
# 1  Thayarwady-1           42498  209              6  Bago       27877
#
#   votes_cast candidate party percent  votes
# 0      32283   San Win   NLD      55  15309
# 1      32283    Tin Yu   NUP      34   9363
#    constituency eligible_voters line num_candidates state valid_votes  \
# 0  Thayarwady-2           42597  213              6  Bago       24473
# 1  Thayarwady-2           42597  213              6  Bago       24473
#
#   votes_cast      candidate party percent  votes
# 0      28446      Maung Aye   NLD      60  14747
# 1      28446  Maj Aung Khin   NUP      33   8015
#   constituency eligible_voters line num_candidates       state valid_votes  \
# 0     Maubin-1           78823  217              6  Ayeyarwady       49787
# 1     Maubin-1           78823  217              6  Ayeyarwady       49787
#
#   votes_cast   candidate party percent  votes
# 0      57426   Chit Than   NUP      48  23861
# 1      57426  Thaung Aye   NLD      45  22497
#   constituency eligible_voters line num_candidates       state valid_votes  \
# 0     Maubin-2           79605  221              5  Ayeyarwady       46628
# 1     Maubin-2           79605  221              5  Ayeyarwady       46628
#
#   votes_cast    candidate party percent  votes
# 0      52563    Hla Myint   NLD      55  25855
# 1      52563  Aung Thaung   NUP      40  18828
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0        Kalaw           62010  225              6  Shan       31178
# 1        Kalaw           62010  225              6  Shan       31178
# 2        Kalaw           62010  225              6  Shan       31178
#
#   votes_cast   candidate  party percent  votes
# 0      37984  Myint Than  UDLDP      36  11232
# 1      37984  Tommy Aung    NLD      23   7063
# 2      37984    Ngwe Soe    NUP      21   6673
#   constituency eligible_voters line num_candidates   state valid_votes  \
# 0        Mansi            7447  233              4  Kachin        4387
# 1        Mansi            7447  233              4  Kachin        4387
# 2        Mansi            7447  233              4  Kachin        4387
#
#   votes_cast       candidate party percent votes
# 0       5362      J.M. Nolla   NLD      55  2434
# 1       5362  Phauyam Kamtwe   NUP      27  1182
# 2       5362          Ba Maw  SNLD      13   550
#             constituency eligible_voters line num_candidates     state  \
# 0  Mandalay North West-1           46015  241              6  Mandalay
# 1  Mandalay North West-1           46015  241              6  Mandalay
#
#   valid_votes votes_cast      candidate party percent  votes
# 0       36630      38138  Tin Aung Aung   NLD      80  29443
# 1       36630      38138      Thein Hla   NUP      16   5703
#             constituency eligible_voters line num_candidates     state  \
# 0  Mandalay South East-1           46419  245              8  Mandalay
# 1  Mandalay South East-1           46419  245              8  Mandalay
#
#   valid_votes votes_cast  candidate party percent  votes
# 0       36910      39253  Tin Nyunt   NLD      80  29642
# 1       36910      39253    Than Oo   NUP      14   5321
#             constituency eligible_voters line num_candidates     state  \
# 0  Mandalay South East-2           58988  249              6  Mandalay
# 1  Mandalay South East-2           58988  249              6  Mandalay
#
#   valid_votes votes_cast   candidate party percent  votes
# 0       43002      46326  Ohn Kyaing   NLD      76  32718
# 1       43002      46326    Min Kyaw   NUP      20   8608
#    constituency eligible_voters line num_candidates        state valid_votes  \
# 0  Thayetchaung           33182  253              4  Tanintharyi       17038
# 1  Thayetchaung           33182  253              4  Tanintharyi       17038
#
#   votes_cast  candidate party percent  votes
# 0      21697  Tin Myint   NLD      91  15522
# 1      21697    Nay Win   NUP       8   1305
#   constituency eligible_voters line num_candidates        state valid_votes  \
# 0   Launglon-1           37442  257              3  Tanintharyi       19614
# 1   Launglon-1           37442  257              3  Tanintharyi       19614
#
#   votes_cast        candidate party percent  votes
# 0      25133           Hla Pe   NLD      88  17241
# 1      25133  Col. Aung Myint   NUP      11   2135
#   constituency eligible_voters line num_candidates        state valid_votes  \
# 0   Launglon-2           33723  261              3  Tanintharyi       18015
# 1   Launglon-2           33723  261              3  Tanintharyi       18015
#
#   votes_cast    candidate party percent  votes
# 0      22759    Chain Hin   NLD      81  14667
# 1      22759  Seinn Maung   NUP      17   3143
#       constituency eligible_voters line num_candidates        state  \
# 0  Dawei-1 [Tavoy]           34527  265              3  Tanintharyi
# 1  Dawei-1 [Tavoy]           34527  265              3  Tanintharyi
#
#   valid_votes votes_cast      candidate party percent  votes
# 0       20110      23456      Soe Nyunt   NLD      85  17059
# 1       20110      23456  Col. Than Hla   NUP      13   2598
#   constituency eligible_voters line num_candidates        state valid_votes  \
# 0      Dawei-2           34766  269              3  Tanintharyi       20656
# 1      Dawei-2           34766  269              3  Tanintharyi       20656
#
#   votes_cast      candidate    party percent  votes
# 0      23677       Myo Aung      NLD      87  17906
# 1      23677  Lt-Col Ba Hla  Unknown      11   2329
#    constituency eligible_voters line num_candidates state valid_votes  \
# 0  Kyaikmaraw-1           39948  274              5   Mon       19968
# 1  Kyaikmaraw-1           39948  274              5   Mon       19968
# 2  Kyaikmaraw-1           39948  274              5   Mon       19968
#
#   votes_cast       candidate party percent  votes
# 0      24640     Myint Thein   NLD      53  10576
# 1      24640     Nai Pan Hla  MNDF      23   4666
# 2      24640  Daw Thein Kyaw   NUP      18   3507
#    constituency eligible_voters line num_candidates state valid_votes  \
# 0  Kyaikmaraw-2           44824  282              6   Mon       27517
# 1  Kyaikmaraw-2           44824  282              6   Mon       27517
# 2  Kyaikmaraw-2           44824  282              6   Mon       27517
#
#   votes_cast       candidate party percent  votes
# 0      32550  Nai Khin Maung  MNDF      42  11528
# 1      32550        Tin Ngwe   NLD      41  11270
# 2      32550      Bo Kya Gyi   NUP      12   3211
#   constituency eligible_voters line num_candidates       state valid_votes  \
# 0     Dedaye-1           49076  290              3  Ayeyarwady       30884
# 1     Dedaye-1           49076  290              3  Ayeyarwady       30884
#
#   votes_cast     candidate party percent  votes
# 0      35788     Myo Nyunt   NLD      58  17957
# 1      35788  Capt Tun Aye   NUP      36  11200
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0    Yedashe-1           42297  294              4  Bago       27413
# 1    Yedashe-1           42297  294              4  Bago       27413
#
#   votes_cast      candidate party percent  votes
# 0      32544  Dr. Kyaw Kyaw   NLD      58  15874
# 1      32544      Chit Kyin   NUP      38  10541
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0    Yedashe-2           43647  298              3  Bago       29014
# 1    Yedashe-2           43647  298              3  Bago       29014
#
#   votes_cast  candidate party percent  votes
# 0      32784   Tun Aung   NLD      61  17571
# 1      32784  Aung Khin   NUP      36  10512
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0        Pyu-1           47205  302              4  Bago       27392
# 1        Pyu-1           47205  302              4  Bago       27392
#
#   votes_cast  candidate party percent  votes
# 0      31432  Aung Than   NLD      66  18067
# 1      31432  Nyunt Han   NUP      31   8601
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0        Pyu-2           65024  306              5  Bago       36948
# 1        Pyu-2           65024  306              5  Bago       36948
#
#   votes_cast  candidate party percent  votes
# 0      41432  Soe Maung   NLD      64  23588
# 1      41432    Tun Kyi   WUO      33  12112
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0    Htantabin           50435  311              4  Bago       30089
# 1    Htantabin           50435  311              4  Bago       30089
#
#   votes_cast   candidate party percent  votes
# 0      36471  Chit Maung   NLD      65  19665
# 1      36471     Tin Win   NUP      22   6712
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0     Oktwin-1           32918  315              5  Bago       18228
# 1     Oktwin-1           32918  315              5  Bago       18228
#
#   votes_cast        candidate party percent  votes
# 0      23535         Thein Oo   NLD      60  10881
# 1      23535  Lt-Col Khin Hla   NUP      28   5029
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0     Oktwin-2           31257  319              4  Bago       19561
# 1     Oktwin-2           31257  319              4  Bago       19561
#
#   votes_cast         candidate party percent  votes
# 0      22696    Khin Maung Win   NLD      63  12357
# 1      22696  Lt-Col Hla Myint   NUP      32   6215
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0   Myingyan-1           81169  323              6  Mandalay       59943
# 1   Myingyan-1           81169  323              6  Mandalay       59943
#
#   votes_cast            candidate party percent  votes
# 0      64928             Paw Khin   NLD      70  42015
# 1      64928  Col. Khin Maung Win   NUP      26  15814
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0   Myingyan-2           80385  327              4  Mandalay       57415
# 1   Myingyan-2           80385  327              4  Mandalay       57415
#
#   votes_cast        candidate party percent  votes
# 0      62136  Maung Maung Win   NLD      68  39088
# 1      62136     Maj. Pe Than   NUP      30  17444
#   constituency eligible_voters line num_candidates  state valid_votes  \
# 0      Pasawng            7753  331              4  Kayah        3121
# 1      Pasawng            7753  331              4  Kayah        3121
#
#   votes_cast     candidate party percent votes
# 0       3574  Saw Tar Rutu   NUP      52  1621
# 1       3574     Maung Gyi   NLD      45  1406
#   constituency eligible_voters line num_candidates  state valid_votes  \
# 0       Pruhso            9237  335              4  Kayah        2739
# 1       Pruhso            9237  335              4  Kayah        2739
# 2       Pruhso            9237  335              4  Kayah        2739
#
#   votes_cast        candidate party percent votes
# 0       3330       Daw Oo Reh   NLD      39  1070
# 1       3330           Hta Ru  KNLD      36   981
# 2       3330  Edward Pyu Aung   WUO      16   435
#   constituency eligible_voters line num_candidates  state valid_votes  \
# 0   Dimawhso-1           12187  344              5  Kayah        4778
# 1   Dimawhso-1           12187  344              5  Kayah        4778
# 2   Dimawhso-1           12187  344              5  Kayah        4778
#
#   votes_cast       candidate party percent votes
# 0       5658  Khin Maung Cho  KNLD      48  2298
# 1       5658          Pha Bu   NUP      27  1298
# 2       5658           Dereh   NLD      22  1028
#   constituency eligible_voters line num_candidates  state valid_votes  \
# 0   Dimawhso-2           12209  352              3  Kayah        7044
# 1   Dimawhso-2           12209  352              3  Kayah        7044
# 2   Dimawhso-2           12209  352              3  Kayah        7044
#
#   votes_cast     candidate party percent votes
# 0       8535    Victor Lay  KNLD      66  4614
# 1       8535  Saw Po Mying   NLD      19  1350
# 2       8535      Saw Wari   PUO      15  1080
#   constituency eligible_voters line num_candidates  state valid_votes  \
# 0     Loikaw-1           19854  361              4  Kayah       11647
# 1     Loikaw-1           19854  361              4  Kayah       11647
# 2     Loikaw-1           19854  361              4  Kayah       11647
#
#   votes_cast candidate party percent votes
# 0      12659   Po Thin   NLD      53  6184
# 1      12659  Kyaw Din   NUP      26  3041
# 2      12659   Sha Reh  KNLD      18  2043
#   constituency eligible_voters line num_candidates  state valid_votes  \
# 0     Loikaw-2           21536  369              6  Kayah       10688
# 1     Loikaw-2           21536  369              6  Kayah       10688
# 2     Loikaw-2           21536  369              6  Kayah       10688
#
#   votes_cast   candidate party percent votes
# 0      12272  Teddy Buyi   NLD      58  6182
# 1      12272     Nay Win   NUP      22  2399
# 2      12272    Sao Phyu  KNLD      13  1349
#   constituency eligible_voters line num_candidates  state valid_votes  \
# 0      Bawlake            2575  377              4  Kayah        1426
# 1      Bawlake            2575  377              4  Kayah        1426
# 2      Bawlake            2575  377              4  Kayah        1426
# 3      Bawlake            2575  377              4  Kayah        1426
#
#   votes_cast     candidate        party percent votes
# 0       1831    Aung Thein          NUP      49   697
# 1       1831    Khin Maung  Independent      23   325
# 2       1831         Mirei         KNLD      17   247
# 3       1831  Dr. Tun Kyaw         UNDP      11   157
#   constituency eligible_voters line num_candidates  state valid_votes  \
# 0       Shataw            2546  388              4  Kayah         735
# 1       Shataw            2546  388              4  Kayah         735
# 2       Shataw            2546  388              4  Kayah         735
#
#   votes_cast candidate party percent votes
# 0        871  Aung Tin   NLD      57   417
# 1        871  Tha Shin   NUP      27   201
# 2        871     Ku Du  KNLD      16   117
#      constituency eligible_voters line num_candidates state valid_votes  \
# 0  Thanbyuzayat-1           37004  396              5   Mon       24156
# 1  Thanbyuzayat-1           37004  396              5   Mon       24156
# 2  Thanbyuzayat-1           37004  396              5   Mon       24156
#
#   votes_cast        candidate party percent  votes
# 0      27185  Maung Maung Gyi   NLD      51  12250
# 1      27185   Sein Mya Maung  MNDF      34   8113
# 2      27185          Tin Tun   NUP      13   3081
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0     Thegon-1           42114  406              4  Bago       24086
# 1     Thegon-1           42114  406              4  Bago       24086
# 2     Thegon-1           42114  406              4  Bago       24086
#
#   votes_cast  candidate party percent  votes
# 0      28353        Aye   NLD      51  12179
# 1      28353  Thant Sin   NUP      31   7447
# 2      28353    Tin Win  UNDP      12   2934
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0     Thegon-2           40248  414              4  Bago       24925
# 1     Thegon-2           40248  414              4  Bago       24925
# 2     Thegon-2           40248  414              4  Bago       24925
#
#   votes_cast            candidate party percent  votes
# 0      28050            Thein Tun   NLD      58  14416
# 1      28050   Col. Yan Naung Soe   PUO      26   6598
# 2      28050  Dr Tin Ko Ko Hlaing  UNDP      11   2732
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0  Shwedaung-1           40926  420              7  Bago       27709
# 1  Shwedaung-1           40926  420              7  Bago       27709
# 2  Shwedaung-1           40926  420              7  Bago       27709
#
#   votes_cast   candidate party percent  votes
# 0      30797   Than Kywe   NLD      59  16280
# 1      30797    Aye Lwin   NUP      27   7351
# 2      30797  Thein Htut  UNDP      12   3405
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0  Shwedaung-2           40989  428              6  Bago       23976
# 1  Shwedaung-2           40989  428              6  Bago       23976
#
#   votes_cast  candidate party percent  votes
# 0      27001  Paik Chon   NLD      65  15635
# 1      27001   Htwe Han   NUP      28   6739
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0    Paungde-1           40222  432              4  Bago       24329
# 1    Paungde-1           40222  432              4  Bago       24329
#
#   votes_cast      candidate party percent  votes
# 0      29939      Ohn Naing   NLD      64  15589
# 1      29939  Maj. Aung Gyi   NUP      21   5112
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0    Paungde-2           39381  436              4  Bago       23846
# 1    Paungde-2           39381  436              4  Bago       23846
#
#   votes_cast        candidate party percent  votes
# 0      29545         Aye Than   NLD      76  18005
# 1      29545  Aung Than Mying   NUP      15   3591
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0    Padaung-1           42763  440              5  Bago       23077
# 1    Padaung-1           42763  440              5  Bago       23077
#
#   votes_cast        candidate party percent  votes
# 0      26532          Tin Ohn   NLD      66  15133
# 1      26532  Col. Oo Saw Hla   NUP      26   6029
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0    Padaung-2           44615  444              5  Bago       27023
# 1    Padaung-2           44615  444              5  Bago       27023
#
#   votes_cast  candidate party percent  votes
# 0      31106  Thein Han   NLD      69  18050
# 1      31106  Saw Thein   NUP      28   7510
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0     Monywa-1           82559  448              5  Sagaing       61225
# 1     Monywa-1           82559  448              5  Sagaing       61225
#
#   votes_cast candidate party percent  votes
# 0      65476   Kyi Soe   NLD      81  49556
# 1      65476   Ba Htwe   WUO      15   8978
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0     Monywa-2           81434  453              7  Sagaing       60695
# 1     Monywa-2           81434  453              7  Sagaing       60695
#
#   votes_cast      candidate party percent  votes
# 0      64205       Saw Aung   NLD      79  47933
# 1      64205  Maj. Sein Win   NUP      17  10512
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0   Salingyi-1           34866  457              4  Sagaing       23512
# 1   Salingyi-1           34866  457              4  Sagaing       23512
#
#   votes_cast          candidate party percent  votes
# 0      25263     Khin Maung Kyi   NLD      77  18126
# 1      25263  Maj-Gen Pe Myaing   NUP      21   4941
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0   Salingyi-2           32356  461              3  Sagaing       21421
# 1   Salingyi-2           32356  461              3  Sagaing       21421
#
#   votes_cast candidate party percent  votes
# 0      24513  Sein Yan   NLD      66  14092
# 1      24513      Kyaw   PUO      33   6993
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0       Pale-1           34071  466              3  Sagaing       23045
# 1       Pale-1           34071  466              3  Sagaing       23045
#
#   votes_cast        candidate party percent  votes
# 0      26498        Than Sein   NLD      69  15874
# 1      26498  Capt. Aung Than   NUP      30   6903
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0       Pale-2           33195  470              4  Sagaing       20759
# 1       Pale-2           33195  470              4  Sagaing       20759
#
#   votes_cast     candidate party percent  votes
# 0      24264  Dr. Tint Swe   NLD      61  12693
# 1      24264   Maj. Tin Oo   NUP      35   7335
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0       Kani-1           30501  474              3  Sagaing       22147
# 1       Kani-1           30501  474              3  Sagaing       22147
#
#   votes_cast        candidate party percent  votes
# 0      23751  Khin Maung Than   NLD      78  17238
# 1      23751      P. Kyaw Han   NUP      21   4646
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0       Kani-2           31839  478              3  Sagaing       22755
# 1       Kani-2           31839  478              3  Sagaing       22755
#
#   votes_cast  candidate party percent  votes
# 0      24972  Thant Zin   NLD      83  18781
# 1      24972  Ba Hlaing   NUP      17   3781
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0     Chaung-U           52736  482              6  Sagaing       36367
# 1     Chaung-U           52736  482              6  Sagaing       36367
#
#   votes_cast  candidate party percent  votes
# 0      41320    Ant Kyi   NLD      72  26107
# 1      41320  Myo Myint   NUP      25   8958
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0   Yinmabin-1           31513  486              5  Sagaing       20876
# 1   Yinmabin-1           31513  486              5  Sagaing       20876
#
#   votes_cast  candidate party percent  votes
# 0      23399  Bo Thaung   NLD      75  15647
# 1      23399   Chan Tun   PUO      22   4496
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0   Yinmabin-2           31162  491              4  Sagaing       21278
# 1   Yinmabin-2           31162  491              4  Sagaing       21278
#
#   votes_cast     candidate party percent  votes
# 0      24424  Tin Tun Aung   NLD      72  15390
# 1      24424    Myint Aung   NUP      25   5298
#   constituency eligible_voters line num_candidates state valid_votes  \
# 0      Ywangan           28996  496              3  Shan       18168
# 1      Ywangan           28996  496              3  Shan       18168
# 2      Ywangan           28996  496              3  Shan       18168
#
#   votes_cast   candidate  party percent votes
# 0      23488  Aung Thein   UNDP      44  7905
# 1      23488     Aye San    NUP      29  5295
# 2      23488   Nyunt Tin  UDLDP      27  4968
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0   Taungtha-1           62509  505              4  Mandalay       44393
# 1   Taungtha-1           62509  505              4  Mandalay       44393
#
#   votes_cast       candidate party percent  votes
# 0      47853     Chit Khaing   NLD      68  30026
# 1      47853  Khin Maung Win   PUO      30  13461
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0   Taungtha-2           63115  510              4  Mandalay       42749
# 1   Taungtha-2           63115  510              4  Mandalay       42749
#
#   votes_cast      candidate party percent  votes
# 0      47343       Than Tun   NLD      70  30086
# 1      47343  Aye Maung Kyi   NUP      28  12020
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0     Minbya-1           40237  514              7  Rakhine       22286
# 1     Minbya-1           40237  514              7  Rakhine       22286
# 2     Minbya-1           40237  514              7  Rakhine       22286
#
#   votes_cast    candidate  party percent  votes
# 0      27084  Maung Myint    RDL      55  12301
# 1      27084      Nyi Nyi    NUP      17   3800
# 2      27084   Khin Maung  NDPHR      15   3292
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0     Minbya-2           37764  523              6  Rakhine       20431
# 1     Minbya-2           37764  523              6  Rakhine       20431
# 2     Minbya-2           37764  523              6  Rakhine       20431
#
#   votes_cast         candidate party percent  votes
# 0      25233           Tun Win   RDL      58  11899
# 1      25233  Salai Kyaw Naing  CNLD      14   2889
# 2      25233       Tun Hla Pru   NUP      14   2871
#   constituency eligible_voters line num_candidates   state valid_votes  \
# 0       Shwegu           26266  532              4  Kachin       15483
# 1       Shwegu           26266  532              4  Kachin       15483
#
#   votes_cast     candidate party percent  votes
# 0      17790  Daw Sein Tin   NLD      71  11038
# 1      17790     Aung Than   NUP      26   4052
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0    Natogyi-1           53791  536              7  Mandalay       37129
# 1    Natogyi-1           53791  536              7  Mandalay       37129
#
#   votes_cast         candidate party percent  votes
# 0      40749           Pan Tha   NLD      67  25034
# 1      40749  Maj. Nyunt Thein   WUO      27   9883
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0    Natogyi-2           53780  541              7  Mandalay       35723
# 1    Natogyi-2           53780  541              7  Mandalay       35723
#
#   votes_cast    candidate party percent  votes
# 0      38887  Seinn Maung   NLD      62  22303
# 1      38887     Than Tun   NUP      26   9210
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0   Nyaung-U-1           62471  545              4  Mandalay       43241
# 1   Nyaung-U-1           62471  545              4  Mandalay       43241
#
#   votes_cast candidate party percent  votes
# 0      48605       Cho   NLD      69  29884
# 1      48605  Saw Lwin   NUP      27  11549
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0   Nyaung-U-2           62910  549              3  Mandalay       40648
# 1   Nyaung-U-2           62910  549              3  Mandalay       40648
#
#   votes_cast   candidate party percent  votes
# 0      45294      Pe Tin   NLD      68  27691
# 1      45294  Than Shein   NUP      28  11451
#      constituency eligible_voters line num_candidates     state valid_votes  \
# 0  Kyaukpadaung-1           72304  553              4  Mandalay       49837
# 1  Kyaukpadaung-1           72304  553              4  Mandalay       49837
#
#   votes_cast        candidate party percent  votes
# 0      55038           Bo Zan   NLD      71  35320
# 1      55038  Capt. Aung Kyin   PUO      24  12060
#      constituency eligible_voters line num_candidates     state valid_votes  \
# 0  Kyaukpadaung-2           72245  558              4  Mandalay       52215
# 1  Kyaukpadaung-2           72245  558              4  Mandalay       52215
#
#   votes_cast candidate party percent  votes
# 0      58629  Ngwe Tun   NLD      68  35735
# 1      58629  Ye Maung   NUP      26  13394
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0     Tatkon-1           53097  562              4  Mandalay       38092
# 1     Tatkon-1           53097  562              4  Mandalay       38092
#
#   votes_cast    candidate party percent  votes
# 0      41960    Wan Maung   NLD      67  25422
# 1      41960  Col. Hla Bu   NUP      26   9766
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0     Tatkon-2           53515  566              4  Mandalay       36312
# 1     Tatkon-2           53515  566              4  Mandalay       36312
#
#   votes_cast        candidate party percent  votes
# 0      41886       Win Hlaing   NLD      71  25894
# 1      41886  Maj. Aung Maung   NUP      22   8094
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0    Pyawbwe-1           63462  570              5  Mandalay       45075
# 1    Pyawbwe-1           63462  570              5  Mandalay       45075
#
#   votes_cast       candidate party percent  votes
# 0      49801  Khin Maung Nyo   NLD      56  25272
# 1      49801      Thein Aung   NUP      40  17984
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0    Pyawbwe-2           61031  574              4  Mandalay       36739
# 1    Pyawbwe-2           61031  574              4  Mandalay       36739
#
#   votes_cast   candidate party percent  votes
# 0      43280      Hla Pe   NLD      56  20527
# 1      43280  Ohn Hlaing   NUP      37  13682
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0   Yamethin-1           55779  578              5  Mandalay       40579
# 1   Yamethin-1           55779  578              5  Mandalay       40579
# 2   Yamethin-1           55779  578              5  Mandalay       40579
#
#   votes_cast          candidate party percent  votes
# 0      45228  Maung Maung Myint   NLD      47  19049
# 1      45228           Tun Phyu   NUP      30  12284
# 2      45228          Htaik Thu    DP      13   5389
#   constituency eligible_voters line num_candidates     state valid_votes  \
# 0   Yamethin-2           54319  586              5  Mandalay       36575
# 1   Yamethin-2           54319  586              5  Mandalay       36575
#
#   votes_cast         candidate party percent  votes
# 0      41270  Maung Maung Than   NLD      41  15082
# 1      41270        Kyaw Nyunt   NUP      37  13501
#   constituency eligible_voters line num_candidates    state valid_votes  \
# 0     Sittwe-1           49899  590              8  Rakhine       30332
# ...
# 0      26081       Nay Win   NLD      67  13379
# 1      26081       Tun Tun   NUP      15   3016
# 2      26081  Aung Pan Tha  APDF      11   2121
#   constituency eligible_voters  line num_candidates   state valid_votes  \
# 0    Sumprabum            1284  2035              2  Kachin         806
# 1    Sumprabum            1284  2035              2  Kachin         806
#
#   votes_cast candidate  party percent votes
# 0        879   Zau Ain  KSNCD      73   589
# 1        879    Nyi Pu    NUP      27   217
#   constituency eligible_voters  line num_candidates   state valid_votes  \
# 0     Khawbude            5997  2040              4  Kachin        3180
# 1     Khawbude            5997  2040              4  Kachin        3180
# 2     Khawbude            5997  2040              4  Kachin        3180
#
#   votes_cast       candidate    party percent votes
# 0       3381      Mapang Sin  Unknown      41  1317
# 1       3381  Jonas Aung Gam      NUP      29   931
# 2       3381         R Gudee    KSNDP      29   924
#   constituency eligible_voters  line num_candidates   state valid_votes  \
# 0    Machambaw            6138  2048              4  Kachin        4082
# 1    Machambaw            6138  2048              4  Kachin        4082
# 2    Machambaw            6138  2048              4  Kachin        4082
#
#   votes_cast     candidate  party percent votes
# 0       4604    N Nang Gam    NLD      38  1532
# 1       4604   Lanang Bawk    NUP      30  1225
# 2       4604  Ding Ra Tang  KSNDP      28  1140
#   constituency eligible_voters  line num_candidates   state valid_votes  \
# 0      Kamaing           11327  2056              6  Kachin        5208
# 1      Kamaing           11327  2056              6  Kachin        5208
# 2      Kamaing           11327  2056              6  Kachin        5208
#
#   votes_cast            candidate party percent votes
# 0       5755            Tin Myint   NLD      49  2550
# 1       5755        N D Zau Tawng  KNCD      26  1266
# 2       5755  Khamda Brang Shaung   NUP      13   687
#   constituency eligible_voters  line num_candidates   state valid_votes  \
# 0        Putao           29900  2064              8  Kachin       17707
# 1        Putao           29900  2064              8  Kachin       17707
# 2        Putao           29900  2064              8  Kachin       17707
#
#   votes_cast   candidate        party percent votes
# 0      21960      Yau Si          NLD      49  8695
# 1      21960  Mi Tung Tu          NUP      17  2951
# 2      21960   Pansa Ram  Independent      11  1895
#   constituency eligible_voters  line num_candidates   state valid_votes  \
# 0       Nogmun            3850  2072              3  Kachin        2877
# 1       Nogmun            3850  2072              3  Kachin        2877
#
#   votes_cast  candidate party percent votes
# 0       3096  M Sin Sar   NUP      78  2231
# 1       3096    Min Zaw   NLD      21   603
#   constituency eligible_voters  line num_candidates    state valid_votes  \
# 0   Maungdaw-1           87174  2076              7  Rakhine       64019
# 1   Maungdaw-1           87174  2076              7  Rakhine       64019
# 2   Maungdaw-1           87174  2076              7  Rakhine       64019
# 3   Maungdaw-1           87174  2076              7  Rakhine       64019
#
#   votes_cast           candidate  party percent  votes
# 0      73633             Ebrahim  NDPHR      51  31360
# 1      73633           Noor Alam  SYLMD      33  21319
# 2      73633     Mohamed Hussein    NLD       1    672
# 3      73633  Capt. Hla Saw Aung    NUP       0    307
#   constituency eligible_voters  line num_candidates    state valid_votes  \
# 0   Maungdaw-2           84166  2086              7  Rakhine       58230
# 1   Maungdaw-2           84166  2086              7  Rakhine       58230
# 2   Maungdaw-2           84166  2086              7  Rakhine       58230
# 3   Maungdaw-2           84166  2086              7  Rakhine       58230
#
#   votes_cast    candidate  party percent  votes
# 0      68440  Fazul Ahmed  NDPHR      43  24881
# 1      68440    Nurul Haq  SYLMD      42  24203
# 2      68440        Rafee    NUP       6   3746
# 3      68440    Abul Faiz    NLD       4   2221
#   constituency eligible_voters  line num_candidates    state valid_votes  \
# 0         Lahe            8847  2098              3  Sagaing        4678
# 1         Lahe            8847  2098              3  Sagaing        4678
# 2         Lahe            8847  2098              3  Sagaing        4678
#
#   votes_cast     candidate  party percent votes
# 0       5511  Khapo Kailon  NHRPP      87  4053
# 1       5511     Mya Maung    NUP      11   510
# 2       5511     Myint Tin    NLD       2   115
#   constituency eligible_voters  line num_candidates    state valid_votes  \
# 0        Leshi            5572  2108              2  Sagaing        4724
# 1        Leshi            5572  2108              2  Sagaing        4724
#
#   votes_cast    candidate  party percent votes
# 0       4951     Dwe Pawt  NHRPP      70  3300
# 1       4951  Law Pau Yaw    NUP      30  1424
#   constituency eligible_voters  line num_candidates   state valid_votes  \
# 0       Chipwe            1753  2114              3  Kachin        1339
# 1       Chipwe            1753  2114              3  Kachin        1339
# 2       Chipwe            1753  2114              3  Kachin        1339
#
#   votes_cast     candidate  party percent votes
# 0       1417  G Bawng Hlan  KSNCD      37   496
# 1       1417       Raw Bon  KSNDP      32   422
# 2       1417    Khaw Sawng    NUP      31   421
#   constituency eligible_voters  line num_candidates   state valid_votes  \
# 0      Hsawlaw             452  2120              4  Kachin         382
# 1      Hsawlaw             452  2120              4  Kachin         382
# 2      Hsawlaw             452  2120              4  Kachin         382
# 3      Hsawlaw             452  2120              4  Kachin         382
#
#   votes_cast             candidate  party percent votes
# 0        397  Mok Myaw Hsan Khawng    NUP      41   158
# 1        397   Han Gau Dawng Zawng    NLD      37   143
# 2        397      Wa BAU Zay Zawng  KSNDP      21    80
# 3        397           Gyone Hawng    KNC       0     1
#              constituency eligible_voters  line num_candidates       state  \
# 0                 Kayan-1           41226     1              4      Yangon
# 1                 Kayan-1           41226     1              4      Yangon
# 0                 Kayan-2           40018     5              6      Yangon
# 1                 Kayan-2           40018     5              6      Yangon
# 0                Wakema-2           72831     9              4  Ayeyarwady
# 1                Wakema-2           72831     9              4  Ayeyarwady
# 2                Wakema-2           72831     9              4  Ayeyarwady
# 0   Mandalay North East-1           37046    18              8    Mandalay
# 1   Mandalay North East-1           37046    18              8    Mandalay
# 0                 Minbu-1           43600    22              6      Magway
# 1                 Minbu-1           43600    22              6      Magway
# 0                 Minbu-2           42102    26              3      Magway
# 1                 Minbu-2           42102    26              3      Magway
# 0   Mandalay North West-2           50451    31              6    Mandalay
# 1   Mandalay North West-2           50451    31              6    Mandalay
# 0                  Ngaphe           21337    35              3      Magway
# 1                  Ngaphe           21337    35              3      Magway
# 0   Mandalay North East-2           38885    39              6    Mandalay
# 1   Mandalay North East-2           38885    39              6    Mandalay
# 0              Kunyangonn           56590    43              6      Yangon
# 1              Kunyangonn           56590    43              6      Yangon
# 0            Patheingyi-1           36244    47              6    Mandalay
# 1            Patheingyi-1           36244    47              6    Mandalay
# 0            Patheingyi-2           34087    51              7    Mandalay
# 1            Patheingyi-2           34087    51              7    Mandalay
# 2            Patheingyi-2           34087    51              7    Mandalay
# 0              Kyaiklat-1           45458    56              4  Ayeyarwady
# 1              Kyaiklat-1           45458    56              4  Ayeyarwady
# 0              Kyaiklat-2           46027    60              4  Ayeyarwady
# 1              Kyaiklat-2           46027    60              4  Ayeyarwady
# ..                    ...             ...   ...            ...         ...
# 1               Machambaw            6138  2048              4      Kachin
# 2               Machambaw            6138  2048              4      Kachin
# 0                 Kamaing           11327  2056              6      Kachin
# 1                 Kamaing           11327  2056              6      Kachin
# 2                 Kamaing           11327  2056              6      Kachin
# 0                   Putao           29900  2064              8      Kachin
# 1                   Putao           29900  2064              8      Kachin
# 2                   Putao           29900  2064              8      Kachin
# 0                  Nogmun            3850  2072              3      Kachin
# 1                  Nogmun            3850  2072              3      Kachin
# 0              Maungdaw-1           87174  2076              7     Rakhine
# 1              Maungdaw-1           87174  2076              7     Rakhine
# 2              Maungdaw-1           87174  2076              7     Rakhine
# 3              Maungdaw-1           87174  2076              7     Rakhine
# 0              Maungdaw-2           84166  2086              7     Rakhine
# 1              Maungdaw-2           84166  2086              7     Rakhine
# 2              Maungdaw-2           84166  2086              7     Rakhine
# 3              Maungdaw-2           84166  2086              7     Rakhine
# 0                    Lahe            8847  2098              3     Sagaing
# 1                    Lahe            8847  2098              3     Sagaing
# 2                    Lahe            8847  2098              3     Sagaing
# 0                   Leshi            5572  2108              2     Sagaing
# 1                   Leshi            5572  2108              2     Sagaing
# 0                  Chipwe            1753  2114              3      Kachin
# 1                  Chipwe            1753  2114              3      Kachin
# 2                  Chipwe            1753  2114              3      Kachin
# 0                 Hsawlaw             452  2120              4      Kachin
# 1                 Hsawlaw             452  2120              4      Kachin
# 2                 Hsawlaw             452  2120              4      Kachin
# 3                 Hsawlaw             452  2120              4      Kachin
#
#    valid_votes votes_cast             candidate        party percent  votes
# 0        31328      33996            Kyaw Thwin          NLD      68  21278
# 1        31328      33996            Than Maung          NUP      27   8408
# 0        28841      32524         Tin Maung Win          NLD      60  17428
# 1        28841      32524               Zaw Win          NUP      35  10027
# 0        41528      49584         Col. Thet Wai          NUP      43  17893
# 1        41528      49584             Myint Swe          LDP      30  12307
# 2        41528      49584      Dr. Saw Bei Htoo          UKL      23   9629
# 0        29005      30833       Maung Maung Aye          NLD      83  24100
# 1        29005      30833              Kyaw Aye          WUO      10   2822
# 0        28506      31928             Soe Myint          NLD      75  21324
# 1        28506      31928        Col. Kyi Thein          WUO      20   5685
# 0        24456      28063               Hla Soe          NLD      85  20719
# 1        24456      28063                   Win      LDP-141      11   2621
# 0        35234     380943              Aung Soe          NLD      67  23576
# 1        35234     380943          Col. Chit Yi          NUP      31  10782
# 0        15107      17077              Kyi Lwin          NLD      72  10807
# 1        15107      17077              Tin Sein          NUP      26   3945
# 0        29401      30746               Tin Aye          NLD      77  22547
# 1        29401      30746             Tin Maung          NUP      16   4621
# 0        42287      47680                   Gun          NLD      67  28198
# 1        42287      47680            Kyaw Nyunt          NUP      25  10763
# 0        24662      27769       Hsan Nyunt Wain          NLD      66  16336
# 1        24662      27769               Tun Kyi          NUP      29   7206
# 0        24014      27070    Lt-Col San Hla Baw          NLD      58  13870
# 1        24014      27070                Kyaung          PUO      27   6587
# 2        24014      27070             Naing Win  independent      11   2732
# 0        30873      35056              Than Tin          NLD      53  16451
# 1        30873      35056             Maung Mya          NUP      41  12596
# 0        29710      33590               Tin Win          NLD      48  14351
# 1        29710      33590       Saw Myint Thein          NUP      43  12774
# ..         ...        ...                   ...          ...     ...    ...
# 1         4082       4604           Lanang Bawk          NUP      30   1225
# 2         4082       4604          Ding Ra Tang        KSNDP      28   1140
# 0         5208       5755             Tin Myint          NLD      49   2550
# 1         5208       5755         N D Zau Tawng         KNCD      26   1266
# 2         5208       5755   Khamda Brang Shaung          NUP      13    687
# 0        17707      21960                Yau Si          NLD      49   8695
# 1        17707      21960            Mi Tung Tu          NUP      17   2951
# 2        17707      21960             Pansa Ram  Independent      11   1895
# 0         2877       3096             M Sin Sar          NUP      78   2231
# 1         2877       3096               Min Zaw          NLD      21    603
# 0        64019      73633               Ebrahim        NDPHR      51  31360
# 1        64019      73633             Noor Alam        SYLMD      33  21319
# 2        64019      73633       Mohamed Hussein          NLD       1    672
# 3        64019      73633    Capt. Hla Saw Aung          NUP       0    307
# 0        58230      68440           Fazul Ahmed        NDPHR      43  24881
# 1        58230      68440             Nurul Haq        SYLMD      42  24203
# 2        58230      68440                 Rafee          NUP       6   3746
# 3        58230      68440             Abul Faiz          NLD       4   2221
# 0         4678       5511          Khapo Kailon        NHRPP      87   4053
# 1         4678       5511             Mya Maung          NUP      11    510
# 2         4678       5511             Myint Tin          NLD       2    115
# 0         4724       4951              Dwe Pawt        NHRPP      70   3300
# 1         4724       4951           Law Pau Yaw          NUP      30   1424
# 0         1339       1417          G Bawng Hlan        KSNCD      37    496
# 1         1339       1417               Raw Bon        KSNDP      32    422
# 2         1339       1417            Khaw Sawng          NUP      31    421
# 0          382        397  Mok Myaw Hsan Khawng          NUP      41    158
# 1          382        397   Han Gau Dawng Zawng          NLD      37    143
# 2          382        397      Wa BAU Zay Zawng        KSNDP      21     80
# 3          382        397           Gyone Hawng          KNC       0      1
#
# [906 rows x 11 columns]

# %%
candidates_df.to_csv('1990_election_results.csv')
